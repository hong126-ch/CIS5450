# %% [markdown]
# <a href="https://colab.research.google.com/github/hong126-ch/CIS5450/blob/main/20_Module_4_Part_II_SQL_Streaming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Streams in a High-Level System

# %% [markdown]
# ## Basic Setup

# %%
# %set_env SPARK_VERSION=3.5.7
# Out:
# env: SPARK_VERSION=3.5.7

# %% [markdown]
# ## Data Stream Processing
#
# We will be using Spark Streaming (since everyone is familiar with Spark) as well as StreamParse (which is a bit lower-level).

# %% [markdown]
# ### Spark Installation
#
# As a preliminary step, we'll first set Apache Spark up on the current machine.

# %%
## Let's install Apache Spark on Colab

# !wget -nc https://downloads.apache.org/spark/spark-$SPARK_VERSION/spark-$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf spark-$SPARK_VERSION-bin-hadoop3.tgz
# !pip install findspark

import os

os.environ["SPARK_HOME"] = "/content/spark-" + os.environ['SPARK_VERSION'] + "-bin-hadoop3"
# Out:
# --2025-12-02 00:46:44--  https://downloads.apache.org/spark/spark-3.5.7/spark-3.5.7-bin-hadoop3.tgz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.208.237, 2a01:4f9:3a:2c57::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 400914067 (382M) [application/x-gzip]
# Saving to: ‘spark-3.5.7-bin-hadoop3.tgz’
#
# spark-3.5.7-bin-had 100%[===================>] 382.34M  18.4MB/s    in 22s
#
# 2025-12-02 00:47:06 (17.3 MB/s) - ‘spark-3.5.7-bin-hadoop3.tgz’ saved [400914067/400914067]
#
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl.metadata (352 bytes)
# Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %%
import findspark

findspark.init()

import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import *
import pyspark.sql.functions as F
from pyspark.sql import SQLContext

# %%
# Let's set up a connection to local Spark

from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext

spark = SparkSession.builder.appName("Flights").getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# ### Downloading Data from Google Drive
#
# Next, we'll be analyzing **airline flight info** in streaming fashion.  This info started off in a giant data file from the US Department of Transportation's [Bureau of Transportation Statistics](https://www.transtats.bts.gov/Tables.asp?DB_ID=120&DB_Name=Airline%20On-Time%20Performance%20Data&DB_Short_Name=On-Time).
#
# First we need to download it from where it's being publicly shared in Google Drive.

# %%
# !wget -nc https://storage.googleapis.com/penn-cis5450/airlines.csv
# !wget -nc https://storage.googleapis.com/penn-cis5450/airports.csv
# !wget -nc https://storage.googleapis.com/penn-cis5450/ontime.csv
# !wget -nc https://storage.googleapis.com/penn-cis5450/2015-ontime.csv
# Out:
# --2025-12-02 00:48:17--  https://storage.googleapis.com/penn-cis5450/airlines.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.207, 173.194.203.207, 74.125.199.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 359 [text/csv]
# Saving to: ‘airlines.csv’
#
# airlines.csv        100%[===================>]     359  --.-KB/s    in 0s
#
# 2025-12-02 00:48:17 (118 MB/s) - ‘airlines.csv’ saved [359/359]
#
# --2025-12-02 00:48:17--  https://storage.googleapis.com/penn-cis5450/airports.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.207, 173.194.203.207, 74.125.199.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23867 (23K) [text/csv]
# Saving to: ‘airports.csv’
#
# airports.csv        100%[===================>]  23.31K  --.-KB/s    in 0s
#
# 2025-12-02 00:48:17 (100 MB/s) - ‘airports.csv’ saved [23867/23867]
#
# --2025-12-02 00:48:18--  https://storage.googleapis.com/penn-cis5450/ontime.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.207, 173.194.203.207, 74.125.199.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28805770 (27M) [text/csv]
# Saving to: ‘ontime.csv’
#
# ontime.csv          100%[===================>]  27.47M   173MB/s    in 0.2s
#
# 2025-12-02 00:48:18 (173 MB/s) - ‘ontime.csv’ saved [28805770/28805770]
#
# --2025-12-02 00:48:18--  https://storage.googleapis.com/penn-cis5450/2015-ontime.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.207, 173.194.203.207, 74.125.199.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 592406591 (565M) [text/csv]
# Saving to: ‘2015-ontime.csv’
#
# 2015-ontime.csv     100%[===================>] 564.96M   198MB/s    in 2.9s
#
# 2025-12-02 00:48:21 (198 MB/s) - ‘2015-ontime.csv’ saved [592406591/592406591]

# %% [markdown]
# Let's see what we have downloaded...

# %%
# !ls -l /content/*.csv
# Out:
# -rw-r--r-- 1 root root 592406591 Nov 15  2024 /content/2015-ontime.csv
# -rw-r--r-- 1 root root       359 Sep  5  2022 /content/airlines.csv
# -rw-r--r-- 1 root root     23867 Sep  5  2022 /content/airports.csv
# -rw-r--r-- 1 root root  28805770 Nov 15  2024 /content/ontime.csv

# %%
# Now, to demonstrate Spark's incremental processing, we'll break the one-month
# ontime.csv file into segments of 10000 lines each
! split -n 10000 ontime.csv

# !head ontime.csv
# Out:
# "YEAR","MONTH","DAY_OF_MONTH","AIRLINE_ID","CARRIER","FL_NUM","ORIGIN","DEST","ARR_DELAY_NEW","CANCELLED",
# 2018,1,2,19393,"WN","1325","SJU","MCO",0.00,0.00,
# 2018,1,2,19393,"WN","5159","SJU","MCO",0.00,0.00,
# 2018,1,2,19393,"WN","5890","SJU","MCO",9.00,0.00,
# 2018,1,2,19393,"WN","6618","SJU","MCO",0.00,0.00,
# 2018,1,2,19393,"WN","1701","SJU","MDW",8.00,0.00,
# 2018,1,2,19393,"WN","844","SJU","TPA",23.00,0.00,
# 2018,1,2,19393,"WN","4679","SJU","TPA",0.00,0.00,
# 2018,1,2,19393,"WN","6294","SLC","BUR",20.00,0.00,
# 2018,1,2,19393,"WN","5245","SLC","DAL",0.00,0.00,

# %%
# !head airports.csv
# Out:
# IATA_CODE,AIRPORT,CITY,STATE,COUNTRY,LATITUDE,LONGITUDE
# ABE,Lehigh Valley International Airport,Allentown,PA,USA,40.65236,-75.44040
# ABI,Abilene Regional Airport,Abilene,TX,USA,32.41132,-99.68190
# ABQ,Albuquerque International Sunport,Albuquerque,NM,USA,35.04022,-106.60919
# ABR,Aberdeen Regional Airport,Aberdeen,SD,USA,45.44906,-98.42183
# ABY,Southwest Georgia Regional Airport,Albany,GA,USA,31.53552,-84.19447
# ACK,Nantucket Memorial Airport,Nantucket,MA,USA,41.25305,-70.06018
# ACT,Waco Regional Airport,Waco,TX,USA,31.61129,-97.23052
# ACV,Arcata Airport,Arcata/Eureka,CA,USA,40.97812,-124.10862
# ACY,Atlantic City International Airport,Atlantic City,NJ,USA,39.45758,-74.57717

# %%
# !head airlines.csv
# Out:
# IATA_CODE,AIRLINE
# UA,United Air Lines Inc.
# AA,American Airlines Inc.
# US,US Airways Inc.
# F9,Frontier Airlines Inc.
# B6,JetBlue Airways
# OO,Skywest Airlines Inc.
# AS,Alaska Airlines Inc.
# NK,Spirit Air Lines
# WN,Southwest Airlines Co.

# %%
# !ls
# Out:
# 2015-ontime.csv		     xbqn  xdhh  xeyb  xgov  xifp  xjwj  xlnd  xndx
# airlines.csv		     xbqo  xdhi  xeyc  xgow  xifq  xjwk  xlne  xndy
# airports.csv		     xbqp  xdhj  xeyd  xgox  xifr  xjwl  xlnf  xndz
# ontime.csv		     xbqq  xdhk  xeye  xgoy  xifs  xjwm  xlng  xnea
# sample_data		     xbqr  xdhl  xeyf  xgoz  xift  xjwn  xlnh  xneb
# spark-3.5.7-bin-hadoop3      xbqs  xdhm  xeyg  xgpa  xifu  xjwo  xlni  xnec
# spark-3.5.7-bin-hadoop3.tgz  xbqt  xdhn  xeyh  xgpb  xifv  xjwp  xlnj  xned
# xaaa			     xbqu  xdho  xeyi  xgpc  xifw  xjwq  xlnk  xnee
# xaab			     xbqv  xdhp  xeyj  xgpd  xifx  xjwr  xlnl  xnef
# xaac			     xbqw  xdhq  xeyk  xgpe  xify  xjws  xlnm  xneg
# xaad			     xbqx  xdhr  xeyl  xgpf  xifz  xjwt  xlnn  xneh
# xaae			     xbqy  xdhs  xeym  xgpg  xiga  xjwu  xlno  xnei
# xaaf			     xbqz  xdht  xeyn  xgph  xigb  xjwv  xlnp  xnej
# xaag			     xbra  xdhu  xeyo  xgpi  xigc  xjww  xlnq  xnek
# xaah			     xbrb  xdhv  xeyp  xgpj  xigd  xjwx  xlnr  xnel
# xaai			     xbrc  xdhw  xeyq  xgpk  xige  xjwy  xlns  xnem
# xaaj			     xbrd  xdhx  xeyr  xgpl  xigf  xjwz  xlnt  xnen
# xaak			     xbre  xdhy  xeys  xgpm  xigg  xjxa  xlnu  xneo
# xaal			     xbrf  xdhz  xeyt  xgpn  xigh  xjxb  xlnv  xnep
# xaam			     xbrg  xdia  xeyu  xgpo  xigi  xjxc  xlnw  xneq
# xaan			     xbrh  xdib  xeyv  xgpp  xigj  xjxd  xlnx  xner
# xaao			     xbri  xdic  xeyw  xgpq  xigk  xjxe  xlny  xnes
# xaap			     xbrj  xdid  xeyx  xgpr  xigl  xjxf  xlnz  xnet
# xaaq			     xbrk  xdie  xeyy  xgps  xigm  xjxg  xloa  xneu
# xaar			     xbrl  xdif  xeyz  xgpt  xign  xjxh  xlob  xnev
# xaas			     xbrm  xdig  xeza  xgpu  xigo  xjxi  xloc  xnew
# xaat			     xbrn  xdih  xezb  xgpv  xigp  xjxj  xlod  xnex
# xaau			     xbro  xdii  xezc  xgpw  xigq  xjxk  xloe  xney
# xaav			     xbrp  xdij  xezd  xgpx  xigr  xjxl  xlof  xnez
# xaaw			     xbrq  xdik  xeze  xgpy  xigs  xjxm  xlog  xnfa
# xaax			     xbrr  xdil  xezf  xgpz  xigt  xjxn  xloh  xnfb
# xaay			     xbrs  xdim  xezg  xgqa  xigu  xjxo  xloi  xnfc
# xaaz			     xbrt  xdin  xezh  xgqb  xigv  xjxp  xloj  xnfd
# xaba			     xbru  xdio  xezi  xgqc  xigw  xjxq  xlok  xnfe
# xabb			     xbrv  xdip  xezj  xgqd  xigx  xjxr  xlol  xnff
# xabc			     xbrw  xdiq  xezk  xgqe  xigy  xjxs  xlom  xnfg
# xabd			     xbrx  xdir  xezl  xgqf  xigz  xjxt  xlon  xnfh
# xabe			     xbry  xdis  xezm  xgqg  xiha  xjxu  xloo  xnfi
# xabf			     xbrz  xdit  xezn  xgqh  xihb  xjxv  xlop  xnfj
# xabg			     xbsa  xdiu  xezo  xgqi  xihc  xjxw  xloq  xnfk
# xabh			     xbsb  xdiv  xezp  xgqj  xihd  xjxx  xlor  xnfl
# xabi			     xbsc  xdiw  xezq  xgqk  xihe  xjxy  xlos  xnfm
# xabj			     xbsd  xdix  xezr  xgql  xihf  xjxz  xlot  xnfn
# xabk			     xbse  xdiy  xezs  xgqm  xihg  xjya  xlou  xnfo
# xabl			     xbsf  xdiz  xezt  xgqn  xihh  xjyb  xlov  xnfp
# xabm			     xbsg  xdja  xezu  xgqo  xihi  xjyc  xlow  xnfq
# xabn			     xbsh  xdjb  xezv  xgqp  xihj  xjyd  xlox  xnfr
# xabo			     xbsi  xdjc  xezw  xgqq  xihk  xjye  xloy  xnfs
# xabp			     xbsj  xdjd  xezx  xgqr  xihl  xjyf  xloz  xnft
# xabq			     xbsk  xdje  xezy  xgqs  xihm  xjyg  xlpa  xnfu
# xabr			     xbsl  xdjf  xezz  xgqt  xihn  xjyh  xlpb  xnfv
# xabs			     xbsm  xdjg  xfaa  xgqu  xiho  xjyi  xlpc  xnfw
# xabt			     xbsn  xdjh  xfab  xgqv  xihp  xjyj  xlpd  xnfx
# xabu			     xbso  xdji  xfac  xgqw  xihq  xjyk  xlpe  xnfy
# xabv			     xbsp  xdjj  xfad  xgqx  xihr  xjyl  xlpf  xnfz
# xabw			     xbsq  xdjk  xfae  xgqy  xihs  xjym  xlpg  xnga
# xabx			     xbsr  xdjl  xfaf  xgqz  xiht  xjyn  xlph  xngb
# xaby			     xbss  xdjm  xfag  xgra  xihu  xjyo  xlpi  xngc
# xabz			     xbst  xdjn  xfah  xgrb  xihv  xjyp  xlpj  xngd
# xaca			     xbsu  xdjo  xfai  xgrc  xihw  xjyq  xlpk  xnge
# xacb			     xbsv  xdjp  xfaj  xgrd  xihx  xjyr  xlpl  xngf
# xacc			     xbsw  xdjq  xfak  xgre  xihy  xjys  xlpm  xngg
# xacd			     xbsx  xdjr  xfal  xgrf  xihz  xjyt  xlpn  xngh
# xace			     xbsy  xdjs  xfam  xgrg  xiia  xjyu  xlpo  xngi
# xacf			     xbsz  xdjt  xfan  xgrh  xiib  xjyv  xlpp  xngj
# xacg			     xbta  xdju  xfao  xgri  xiic  xjyw  xlpq  xngk
# xach			     xbtb  xdjv  xfap  xgrj  xiid  xjyx  xlpr  xngl
# xaci			     xbtc  xdjw  xfaq  xgrk  xiie  xjyy  xlps  xngm
# xacj			     xbtd  xdjx  xfar  xgrl  xiif  xjyz  xlpt  xngn
# xack			     xbte  xdjy  xfas  xgrm  xiig  xjza  xlpu  xngo
# xacl			     xbtf  xdjz  xfat  xgrn  xiih  xjzb  xlpv  xngp
# xacm			     xbtg  xdka  xfau  xgro  xiii  xjzc  xlpw  xngq
# xacn			     xbth  xdkb  xfav  xgrp  xiij  xjzd  xlpx  xngr
# xaco			     xbti  xdkc  xfaw  xgrq  xiik  xjze  xlpy  xngs
# xacp			     xbtj  xdkd  xfax  xgrr  xiil  xjzf  xlpz  xngt
# xacq			     xbtk  xdke  xfay  xgrs  xiim  xjzg  xlqa  xngu
# xacr			     xbtl  xdkf  xfaz  xgrt  xiin  xjzh  xlqb  xngv
# xacs			     xbtm  xdkg  xfba  xgru  xiio  xjzi  xlqc  xngw
# xact			     xbtn  xdkh  xfbb  xgrv  xiip  xjzj  xlqd  xngx
# xacu			     xbto  xdki  xfbc  xgrw  xiiq  xjzk  xlqe  xngy
# xacv			     xbtp  xdkj  xfbd  xgrx  xiir  xjzl  xlqf  xngz
# xacw			     xbtq  xdkk  xfbe  xgry  xiis  xjzm  xlqg  xnha
# xacx			     xbtr  xdkl  xfbf  xgrz  xiit  xjzn  xlqh  xnhb
# xacy			     xbts  xdkm  xfbg  xgsa  xiiu  xjzo  xlqi  xnhc
# xacz			     xbtt  xdkn  xfbh  xgsb  xiiv  xjzp  xlqj  xnhd
# xada			     xbtu  xdko  xfbi  xgsc  xiiw  xjzq  xlqk  xnhe
# xadb			     xbtv  xdkp  xfbj  xgsd  xiix  xjzr  xlql  xnhf
# xadc			     xbtw  xdkq  xfbk  xgse  xiiy  xjzs  xlqm  xnhg
# xadd			     xbtx  xdkr  xfbl  xgsf  xiiz  xjzt  xlqn  xnhh
# xade			     xbty  xdks  xfbm  xgsg  xija  xjzu  xlqo  xnhi
# xadf			     xbtz  xdkt  xfbn  xgsh  xijb  xjzv  xlqp  xnhj
# xadg			     xbua  xdku  xfbo  xgsi  xijc  xjzw  xlqq  xnhk
# xadh			     xbub  xdkv  xfbp  xgsj  xijd  xjzx  xlqr  xnhl
# xadi			     xbuc  xdkw  xfbq  xgsk  xije  xjzy  xlqs  xnhm
# xadj			     xbud  xdkx  xfbr  xgsl  xijf  xjzz  xlqt  xnhn
# xadk			     xbue  xdky  xfbs  xgsm  xijg  xkaa  xlqu  xnho
# xadl			     xbuf  xdkz  xfbt  xgsn  xijh  xkab  xlqv  xnhp
# xadm			     xbug  xdla  xfbu  xgso  xiji  xkac  xlqw  xnhq
# xadn			     xbuh  xdlb  xfbv  xgsp  xijj  xkad  xlqx  xnhr
# xado			     xbui  xdlc  xfbw  xgsq  xijk  xkae  xlqy  xnhs
# xadp			     xbuj  xdld  xfbx  xgsr  xijl  xkaf  xlqz  xnht
# xadq			     xbuk  xdle  xfby  xgss  xijm  xkag  xlra  xnhu
# xadr			     xbul  xdlf  xfbz  xgst  xijn  xkah  xlrb  xnhv
# xads			     xbum  xdlg  xfca  xgsu  xijo  xkai  xlrc  xnhw
# xadt			     xbun  xdlh  xfcb  xgsv  xijp  xkaj  xlrd  xnhx
# xadu			     xbuo  xdli  xfcc  xgsw  xijq  xkak  xlre  xnhy
# xadv			     xbup  xdlj  xfcd  xgsx  xijr  xkal  xlrf  xnhz
# xadw			     xbuq  xdlk  xfce  xgsy  xijs  xkam  xlrg  xnia
# xadx			     xbur  xdll  xfcf  xgsz  xijt  xkan  xlrh  xnib
# xady			     xbus  xdlm  xfcg  xgta  xiju  xkao  xlri  xnic
# xadz			     xbut  xdln  xfch  xgtb  xijv  xkap  xlrj  xnid
# xaea			     xbuu  xdlo  xfci  xgtc  xijw  xkaq  xlrk  xnie
# xaeb			     xbuv  xdlp  xfcj  xgtd  xijx  xkar  xlrl  xnif
# xaec			     xbuw  xdlq  xfck  xgte  xijy  xkas  xlrm  xnig
# xaed			     xbux  xdlr  xfcl  xgtf  xijz  xkat  xlrn  xnih
# xaee			     xbuy  xdls  xfcm  xgtg  xika  xkau  xlro  xnii
# xaef			     xbuz  xdlt  xfcn  xgth  xikb  xkav  xlrp  xnij
# xaeg			     xbva  xdlu  xfco  xgti  xikc  xkaw  xlrq  xnik
# xaeh			     xbvb  xdlv  xfcp  xgtj  xikd  xkax  xlrr  xnil
# xaei			     xbvc  xdlw  xfcq  xgtk  xike  xkay  xlrs  xnim
# xaej			     xbvd  xdlx  xfcr  xgtl  xikf  xkaz  xlrt  xnin
# xaek			     xbve  xdly  xfcs  xgtm  xikg  xkba  xlru  xnio
# xael			     xbvf  xdlz  xfct  xgtn  xikh  xkbb  xlrv  xnip
# xaem			     xbvg  xdma  xfcu  xgto  xiki  xkbc  xlrw  xniq
# xaen			     xbvh  xdmb  xfcv  xgtp  xikj  xkbd  xlrx  xnir
# xaeo			     xbvi  xdmc  xfcw  xgtq  xikk  xkbe  xlry  xnis
# xaep			     xbvj  xdmd  xfcx  xgtr  xikl  xkbf  xlrz  xnit
# xaeq			     xbvk  xdme  xfcy  xgts  xikm  xkbg  xlsa  xniu
# xaer			     xbvl  xdmf  xfcz  xgtt  xikn  xkbh  xlsb  xniv
# xaes			     xbvm  xdmg  xfda  xgtu  xiko  xkbi  xlsc  xniw
# xaet			     xbvn  xdmh  xfdb  xgtv  xikp  xkbj  xlsd  xnix
# xaeu			     xbvo  xdmi  xfdc  xgtw  xikq  xkbk  xlse  xniy
# xaev			     xbvp  xdmj  xfdd  xgtx  xikr  xkbl  xlsf  xniz
# xaew			     xbvq  xdmk  xfde  xgty  xiks  xkbm  xlsg  xnja
# xaex			     xbvr  xdml  xfdf  xgtz  xikt  xkbn  xlsh  xnjb
# xaey			     xbvs  xdmm  xfdg  xgua  xiku  xkbo  xlsi  xnjc
# xaez			     xbvt  xdmn  xfdh  xgub  xikv  xkbp  xlsj  xnjd
# xafa			     xbvu  xdmo  xfdi  xguc  xikw  xkbq  xlsk  xnje
# xafb			     xbvv  xdmp  xfdj  xgud  xikx  xkbr  xlsl  xnjf
# xafc			     xbvw  xdmq  xfdk  xgue  xiky  xkbs  xlsm  xnjg
# xafd			     xbvx  xdmr  xfdl  xguf  xikz  xkbt  xlsn  xnjh
# xafe			     xbvy  xdms  xfdm  xgug  xila  xkbu  xlso  xnji
# xaff			     xbvz  xdmt  xfdn  xguh  xilb  xkbv  xlsp  xnjj
# xafg			     xbwa  xdmu  xfdo  xgui  xilc  xkbw  xlsq  xnjk
# xafh			     xbwb  xdmv  xfdp  xguj  xild  xkbx  xlsr  xnjl
# xafi			     xbwc  xdmw  xfdq  xguk  xile  xkby  xlss  xnjm
# xafj			     xbwd  xdmx  xfdr  xgul  xilf  xkbz  xlst  xnjn
# xafk			     xbwe  xdmy  xfds  xgum  xilg  xkca  xlsu  xnjo
# xafl			     xbwf  xdmz  xfdt  xgun  xilh  xkcb  xlsv  xnjp
# xafm			     xbwg  xdna  xfdu  xguo  xili  xkcc  xlsw  xnjq
# xafn			     xbwh  xdnb  xfdv  xgup  xilj  xkcd  xlsx  xnjr
# xafo			     xbwi  xdnc  xfdw  xguq  xilk  xkce  xlsy  xnjs
# xafp			     xbwj  xdnd  xfdx  xgur  xill  xkcf  xlsz  xnjt
# xafq			     xbwk  xdne  xfdy  xgus  xilm  xkcg  xlta  xnju
# xafr			     xbwl  xdnf  xfdz  xgut  xiln  xkch  xltb  xnjv
# xafs			     xbwm  xdng  xfea  xguu  xilo  xkci  xltc  xnjw
# xaft			     xbwn  xdnh  xfeb  xguv  xilp  xkcj  xltd  xnjx
# xafu			     xbwo  xdni  xfec  xguw  xilq  xkck  xlte  xnjy
# xafv			     xbwp  xdnj  xfed  xgux  xilr  xkcl  xltf  xnjz
# xafw			     xbwq  xdnk  xfee  xguy  xils  xkcm  xltg  xnka
# xafx			     xbwr  xdnl  xfef  xguz  xilt  xkcn  xlth  xnkb
# xafy			     xbws  xdnm  xfeg  xgva  xilu  xkco  xlti  xnkc
# xafz			     xbwt  xdnn  xfeh  xgvb  xilv  xkcp  xltj  xnkd
# xaga			     xbwu  xdno  xfei  xgvc  xilw  xkcq  xltk  xnke
# xagb			     xbwv  xdnp  xfej  xgvd  xilx  xkcr  xltl  xnkf
# xagc			     xbww  xdnq  xfek  xgve  xily  xkcs  xltm  xnkg
# xagd			     xbwx  xdnr  xfel  xgvf  xilz  xkct  xltn  xnkh
# xage			     xbwy  xdns  xfem  xgvg  xima  xkcu  xlto  xnki
# xagf			     xbwz  xdnt  xfen  xgvh  ximb  xkcv  xltp  xnkj
# xagg			     xbxa  xdnu  xfeo  xgvi  ximc  xkcw  xltq  xnkk
# xagh			     xbxb  xdnv  xfep  xgvj  ximd  xkcx  xltr  xnkl
# xagi			     xbxc  xdnw  xfeq  xgvk  xime  xkcy  xlts  xnkm
# xagj			     xbxd  xdnx  xfer  xgvl  ximf  xkcz  xltt  xnkn
# xagk			     xbxe  xdny  xfes  xgvm  ximg  xkda  xltu  xnko
# xagl			     xbxf  xdnz  xfet  xgvn  ximh  xkdb  xltv  xnkp
# xagm			     xbxg  xdoa  xfeu  xgvo  ximi  xkdc  xltw  xnkq
# xagn			     xbxh  xdob  xfev  xgvp  ximj  xkdd  xltx  xnkr
# xago			     xbxi  xdoc  xfew  xgvq  ximk  xkde  xlty  xnks
# xagp			     xbxj  xdod  xfex  xgvr  ximl  xkdf  xltz  xnkt
# xagq			     xbxk  xdoe  xfey  xgvs  ximm  xkdg  xlua  xnku
# xagr			     xbxl  xdof  xfez  xgvt  ximn  xkdh  xlub  xnkv
# xags			     xbxm  xdog  xffa  xgvu  ximo  xkdi  xluc  xnkw
# xagt			     xbxn  xdoh  xffb  xgvv  ximp  xkdj  xlud  xnkx
# xagu			     xbxo  xdoi  xffc  xgvw  ximq  xkdk  xlue  xnky
# xagv			     xbxp  xdoj  xffd  xgvx  ximr  xkdl  xluf  xnkz
# xagw			     xbxq  xdok  xffe  xgvy  xims  xkdm  xlug  xnla
# xagx			     xbxr  xdol  xfff  xgvz  ximt  xkdn  xluh  xnlb
# xagy			     xbxs  xdom  xffg  xgwa  ximu  xkdo  xlui  xnlc
# xagz			     xbxt  xdon  xffh  xgwb  ximv  xkdp  xluj  xnld
# xaha			     xbxu  xdoo  xffi  xgwc  ximw  xkdq  xluk  xnle
# xahb			     xbxv  xdop  xffj  xgwd  ximx  xkdr  xlul  xnlf
# xahc			     xbxw  xdoq  xffk  xgwe  ximy  xkds  xlum  xnlg
# xahd			     xbxx  xdor  xffl  xgwf  ximz  xkdt  xlun  xnlh
# xahe			     xbxy  xdos  xffm  xgwg  xina  xkdu  xluo  xnli
# xahf			     xbxz  xdot  xffn  xgwh  xinb  xkdv  xlup  xnlj
# xahg			     xbya  xdou  xffo  xgwi  xinc  xkdw  xluq  xnlk
# xahh			     xbyb  xdov  xffp  xgwj  xind  xkdx  xlur  xnll
# xahi			     xbyc  xdow  xffq  xgwk  xine  xkdy  xlus  xnlm
# xahj			     xbyd  xdox  xffr  xgwl  xinf  xkdz  xlut  xnln
# xahk			     xbye  xdoy  xffs  xgwm  xing  xkea  xluu  xnlo
# xahl			     xbyf  xdoz  xfft  xgwn  xinh  xkeb  xluv  xnlp
# xahm			     xbyg  xdpa  xffu  xgwo  xini  xkec  xluw  xnlq
# xahn			     xbyh  xdpb  xffv  xgwp  xinj  xked  xlux  xnlr
# xaho			     xbyi  xdpc  xffw  xgwq  xink  xkee  xluy  xnls
# xahp			     xbyj  xdpd  xffx  xgwr  xinl  xkef  xluz  xnlt
# xahq			     xbyk  xdpe  xffy  xgws  xinm  xkeg  xlva  xnlu
# xahr			     xbyl  xdpf  xffz  xgwt  xinn  xkeh  xlvb  xnlv
# xahs			     xbym  xdpg  xfga  xgwu  xino  xkei  xlvc  xnlw
# xaht			     xbyn  xdph  xfgb  xgwv  xinp  xkej  xlvd  xnlx
# xahu			     xbyo  xdpi  xfgc  xgww  xinq  xkek  xlve  xnly
# xahv			     xbyp  xdpj  xfgd  xgwx  xinr  xkel  xlvf  xnlz
# xahw			     xbyq  xdpk  xfge  xgwy  xins  xkem  xlvg  xnma
# xahx			     xbyr  xdpl  xfgf  xgwz  xint  xken  xlvh  xnmb
# xahy			     xbys  xdpm  xfgg  xgxa  xinu  xkeo  xlvi  xnmc
# xahz			     xbyt  xdpn  xfgh  xgxb  xinv  xkep  xlvj  xnmd
# xaia			     xbyu  xdpo  xfgi  xgxc  xinw  xkeq  xlvk  xnme
# xaib			     xbyv  xdpp  xfgj  xgxd  xinx  xker  xlvl  xnmf
# xaic			     xbyw  xdpq  xfgk  xgxe  xiny  xkes  xlvm  xnmg
# xaid			     xbyx  xdpr  xfgl  xgxf  xinz  xket  xlvn  xnmh
# xaie			     xbyy  xdps  xfgm  xgxg  xioa  xkeu  xlvo  xnmi
# xaif			     xbyz  xdpt  xfgn  xgxh  xiob  xkev  xlvp  xnmj
# xaig			     xbza  xdpu  xfgo  xgxi  xioc  xkew  xlvq  xnmk
# xaih			     xbzb  xdpv  xfgp  xgxj  xiod  xkex  xlvr  xnml
# xaii			     xbzc  xdpw  xfgq  xgxk  xioe  xkey  xlvs  xnmm
# xaij			     xbzd  xdpx  xfgr  xgxl  xiof  xkez  xlvt  xnmn
# xaik			     xbze  xdpy  xfgs  xgxm  xiog  xkfa  xlvu  xnmo
# xail			     xbzf  xdpz  xfgt  xgxn  xioh  xkfb  xlvv  xnmp
# xaim			     xbzg  xdqa  xfgu  xgxo  xioi  xkfc  xlvw  xnmq
# xain			     xbzh  xdqb  xfgv  xgxp  xioj  xkfd  xlvx  xnmr
# xaio			     xbzi  xdqc  xfgw  xgxq  xiok  xkfe  xlvy  xnms
# xaip			     xbzj  xdqd  xfgx  xgxr  xiol  xkff  xlvz  xnmt
# xaiq			     xbzk  xdqe  xfgy  xgxs  xiom  xkfg  xlwa  xnmu
# xair			     xbzl  xdqf  xfgz  xgxt  xion  xkfh  xlwb  xnmv
# xais			     xbzm  xdqg  xfha  xgxu  xioo  xkfi  xlwc  xnmw
# xait			     xbzn  xdqh  xfhb  xgxv  xiop  xkfj  xlwd  xnmx
# xaiu			     xbzo  xdqi  xfhc  xgxw  xioq  xkfk  xlwe  xnmy
# xaiv			     xbzp  xdqj  xfhd  xgxx  xior  xkfl  xlwf  xnmz
# xaiw			     xbzq  xdqk  xfhe  xgxy  xios  xkfm  xlwg  xnna
# xaix			     xbzr  xdql  xfhf  xgxz  xiot  xkfn  xlwh  xnnb
# xaiy			     xbzs  xdqm  xfhg  xgya  xiou  xkfo  xlwi  xnnc
# xaiz			     xbzt  xdqn  xfhh  xgyb  xiov  xkfp  xlwj  xnnd
# xaja			     xbzu  xdqo  xfhi  xgyc  xiow  xkfq  xlwk  xnne
# xajb			     xbzv  xdqp  xfhj  xgyd  xiox  xkfr  xlwl  xnnf
# xajc			     xbzw  xdqq  xfhk  xgye  xioy  xkfs  xlwm  xnng
# xajd			     xbzx  xdqr  xfhl  xgyf  xioz  xkft  xlwn  xnnh
# xaje			     xbzy  xdqs  xfhm  xgyg  xipa  xkfu  xlwo  xnni
# xajf			     xbzz  xdqt  xfhn  xgyh  xipb  xkfv  xlwp  xnnj
# xajg			     xcaa  xdqu  xfho  xgyi  xipc  xkfw  xlwq  xnnk
# xajh			     xcab  xdqv  xfhp  xgyj  xipd  xkfx  xlwr  xnnl
# xaji			     xcac  xdqw  xfhq  xgyk  xipe  xkfy  xlws  xnnm
# xajj			     xcad  xdqx  xfhr  xgyl  xipf  xkfz  xlwt  xnnn
# xajk			     xcae  xdqy  xfhs  xgym  xipg  xkga  xlwu  xnno
# xajl			     xcaf  xdqz  xfht  xgyn  xiph  xkgb  xlwv  xnnp
# xajm			     xcag  xdra  xfhu  xgyo  xipi  xkgc  xlww  xnnq
# xajn			     xcah  xdrb  xfhv  xgyp  xipj  xkgd  xlwx  xnnr
# xajo			     xcai  xdrc  xfhw  xgyq  xipk  xkge  xlwy  xnns
# xajp			     xcaj  xdrd  xfhx  xgyr  xipl  xkgf  xlwz  xnnt
# xajq			     xcak  xdre  xfhy  xgys  xipm  xkgg  xlxa  xnnu
# xajr			     xcal  xdrf  xfhz  xgyt  xipn  xkgh  xlxb  xnnv
# xajs			     xcam  xdrg  xfia  xgyu  xipo  xkgi  xlxc  xnnw
# xajt			     xcan  xdrh  xfib  xgyv  xipp  xkgj  xlxd  xnnx
# xaju			     xcao  xdri  xfic  xgyw  xipq  xkgk  xlxe  xnny
# xajv			     xcap  xdrj  xfid  xgyx  xipr  xkgl  xlxf  xnnz
# xajw			     xcaq  xdrk  xfie  xgyy  xips  xkgm  xlxg  xnoa
# xajx			     xcar  xdrl  xfif  xgyz  xipt  xkgn  xlxh  xnob
# xajy			     xcas  xdrm  xfig  xgza  xipu  xkgo  xlxi  xnoc
# xajz			     xcat  xdrn  xfih  xgzb  xipv  xkgp  xlxj  xnod
# xaka			     xcau  xdro  xfii  xgzc  xipw  xkgq  xlxk  xnoe
# xakb			     xcav  xdrp  xfij  xgzd  xipx  xkgr  xlxl  xnof
# xakc			     xcaw  xdrq  xfik  xgze  xipy  xkgs  xlxm  xnog
# xakd			     xcax  xdrr  xfil  xgzf  xipz  xkgt  xlxn  xnoh
# xake			     xcay  xdrs  xfim  xgzg  xiqa  xkgu  xlxo  xnoi
# xakf			     xcaz  xdrt  xfin  xgzh  xiqb  xkgv  xlxp  xnoj
# xakg			     xcba  xdru  xfio  xgzi  xiqc  xkgw  xlxq  xnok
# xakh			     xcbb  xdrv  xfip  xgzj  xiqd  xkgx  xlxr  xnol
# xaki			     xcbc  xdrw  xfiq  xgzk  xiqe  xkgy  xlxs  xnom
# xakj			     xcbd  xdrx  xfir  xgzl  xiqf  xkgz  xlxt  xnon
# xakk			     xcbe  xdry  xfis  xgzm  xiqg  xkha  xlxu  xnoo
# xakl			     xcbf  xdrz  xfit  xgzn  xiqh  xkhb  xlxv  xnop
# xakm			     xcbg  xdsa  xfiu  xgzo  xiqi  xkhc  xlxw  xnoq
# xakn			     xcbh  xdsb  xfiv  xgzp  xiqj  xkhd  xlxx  xnor
# xako			     xcbi  xdsc  xfiw  xgzq  xiqk  xkhe  xlxy  xnos
# xakp			     xcbj  xdsd  xfix  xgzr  xiql  xkhf  xlxz  xnot
# xakq			     xcbk  xdse  xfiy  xgzs  xiqm  xkhg  xlya  xnou
# xakr			     xcbl  xdsf  xfiz  xgzt  xiqn  xkhh  xlyb  xnov
# xaks			     xcbm  xdsg  xfja  xgzu  xiqo  xkhi  xlyc  xnow
# xakt			     xcbn  xdsh  xfjb  xgzv  xiqp  xkhj  xlyd  xnox
# xaku			     xcbo  xdsi  xfjc  xgzw  xiqq  xkhk  xlye  xnoy
# xakv			     xcbp  xdsj  xfjd  xgzx  xiqr  xkhl  xlyf  xnoz
# xakw			     xcbq  xdsk  xfje  xgzy  xiqs  xkhm  xlyg  xnpa
# xakx			     xcbr  xdsl  xfjf  xgzz  xiqt  xkhn  xlyh  xnpb
# xaky			     xcbs  xdsm  xfjg  xhaa  xiqu  xkho  xlyi  xnpc
# xakz			     xcbt  xdsn  xfjh  xhab  xiqv  xkhp  xlyj  xnpd
# xala			     xcbu  xdso  xfji  xhac  xiqw  xkhq  xlyk  xnpe
# xalb			     xcbv  xdsp  xfjj  xhad  xiqx  xkhr  xlyl  xnpf
# xalc			     xcbw  xdsq  xfjk  xhae  xiqy  xkhs  xlym  xnpg
# xald			     xcbx  xdsr  xfjl  xhaf  xiqz  xkht  xlyn  xnph
# xale			     xcby  xdss  xfjm  xhag  xira  xkhu  xlyo  xnpi
# xalf			     xcbz  xdst  xfjn  xhah  xirb  xkhv  xlyp  xnpj
# xalg			     xcca  xdsu  xfjo  xhai  xirc  xkhw  xlyq  xnpk
# xalh			     xccb  xdsv  xfjp  xhaj  xird  xkhx  xlyr  xnpl
# xali			     xccc  xdsw  xfjq  xhak  xire  xkhy  xlys  xnpm
# xalj			     xccd  xdsx  xfjr  xhal  xirf  xkhz  xlyt  xnpn
# xalk			     xcce  xdsy  xfjs  xham  xirg  xkia  xlyu  xnpo
# xall			     xccf  xdsz  xfjt  xhan  xirh  xkib  xlyv  xnpp
# xalm			     xccg  xdta  xfju  xhao  xiri  xkic  xlyw  xnpq
# xaln			     xcch  xdtb  xfjv  xhap  xirj  xkid  xlyx  xnpr
# xalo			     xcci  xdtc  xfjw  xhaq  xirk  xkie  xlyy  xnps
# xalp			     xccj  xdtd  xfjx  xhar  xirl  xkif  xlyz  xnpt
# xalq			     xcck  xdte  xfjy  xhas  xirm  xkig  xlza  xnpu
# xalr			     xccl  xdtf  xfjz  xhat  xirn  xkih  xlzb  xnpv
# xals			     xccm  xdtg  xfka  xhau  xiro  xkii  xlzc  xnpw
# xalt			     xccn  xdth  xfkb  xhav  xirp  xkij  xlzd  xnpx
# xalu			     xcco  xdti  xfkc  xhaw  xirq  xkik  xlze  xnpy
# xalv			     xccp  xdtj  xfkd  xhax  xirr  xkil  xlzf  xnpz
# xalw			     xccq  xdtk  xfke  xhay  xirs  xkim  xlzg  xnqa
# xalx			     xccr  xdtl  xfkf  xhaz  xirt  xkin  xlzh  xnqb
# xaly			     xccs  xdtm  xfkg  xhba  xiru  xkio  xlzi  xnqc
# xalz			     xcct  xdtn  xfkh  xhbb  xirv  xkip  xlzj  xnqd
# xama			     xccu  xdto  xfki  xhbc  xirw  xkiq  xlzk  xnqe
# xamb			     xccv  xdtp  xfkj  xhbd  xirx  xkir  xlzl  xnqf
# xamc			     xccw  xdtq  xfkk  xhbe  xiry  xkis  xlzm  xnqg
# xamd			     xccx  xdtr  xfkl  xhbf  xirz  xkit  xlzn  xnqh
# xame			     xccy  xdts  xfkm  xhbg  xisa  xkiu  xlzo  xnqi
# xamf			     xccz  xdtt  xfkn  xhbh  xisb  xkiv  xlzp  xnqj
# xamg			     xcda  xdtu  xfko  xhbi  xisc  xkiw  xlzq  xnqk
# xamh			     xcdb  xdtv  xfkp  xhbj  xisd  xkix  xlzr  xnql
# xami			     xcdc  xdtw  xfkq  xhbk  xise  xkiy  xlzs  xnqm
# xamj			     xcdd  xdtx  xfkr  xhbl  xisf  xkiz  xlzt  xnqn
# xamk			     xcde  xdty  xfks  xhbm  xisg  xkja  xlzu  xnqo
# xaml			     xcdf  xdtz  xfkt  xhbn  xish  xkjb  xlzv  xnqp
# xamm			     xcdg  xdua  xfku  xhbo  xisi  xkjc  xlzw  xnqq
# xamn			     xcdh  xdub  xfkv  xhbp  xisj  xkjd  xlzx  xnqr
# xamo			     xcdi  xduc  xfkw  xhbq  xisk  xkje  xlzy  xnqs
# xamp			     xcdj  xdud  xfkx  xhbr  xisl  xkjf  xlzz  xnqt
# xamq			     xcdk  xdue  xfky  xhbs  xism  xkjg  xmaa  xnqu
# xamr			     xcdl  xduf  xfkz  xhbt  xisn  xkjh  xmab  xnqv
# xams			     xcdm  xdug  xfla  xhbu  xiso  xkji  xmac  xnqw
# xamt			     xcdn  xduh  xflb  xhbv  xisp  xkjj  xmad  xnqx
# xamu			     xcdo  xdui  xflc  xhbw  xisq  xkjk  xmae  xnqy
# xamv			     xcdp  xduj  xfld  xhbx  xisr  xkjl  xmaf  xnqz
# xamw			     xcdq  xduk  xfle  xhby  xiss  xkjm  xmag  xnra
# xamx			     xcdr  xdul  xflf  xhbz  xist  xkjn  xmah  xnrb
# xamy			     xcds  xdum  xflg  xhca  xisu  xkjo  xmai  xnrc
# xamz			     xcdt  xdun  xflh  xhcb  xisv  xkjp  xmaj  xnrd
# xana			     xcdu  xduo  xfli  xhcc  xisw  xkjq  xmak  xnre
# xanb			     xcdv  xdup  xflj  xhcd  xisx  xkjr  xmal  xnrf
# xanc			     xcdw  xduq  xflk  xhce  xisy  xkjs  xmam  xnrg
# xand			     xcdx  xdur  xfll  xhcf  xisz  xkjt  xman  xnrh
# xane			     xcdy  xdus  xflm  xhcg  xita  xkju  xmao  xnri
# xanf			     xcdz  xdut  xfln  xhch  xitb  xkjv  xmap  xnrj
# xang			     xcea  xduu  xflo  xhci  xitc  xkjw  xmaq  xnrk
# xanh			     xceb  xduv  xflp  xhcj  xitd  xkjx  xmar  xnrl
# xani			     xcec  xduw  xflq  xhck  xite  xkjy  xmas  xnrm
# xanj			     xced  xdux  xflr  xhcl  xitf  xkjz  xmat  xnrn
# xank			     xcee  xduy  xfls  xhcm  xitg  xkka  xmau  xnro
# xanl			     xcef  xduz  xflt  xhcn  xith  xkkb  xmav  xnrp
# xanm			     xceg  xdva  xflu  xhco  xiti  xkkc  xmaw  xnrq
# xann			     xceh  xdvb  xflv  xhcp  xitj  xkkd  xmax  xnrr
# xano			     xcei  xdvc  xflw  xhcq  xitk  xkke  xmay  xnrs
# xanp			     xcej  xdvd  xflx  xhcr  xitl  xkkf  xmaz  xnrt
# xanq			     xcek  xdve  xfly  xhcs  xitm  xkkg  xmba  xnru
# xanr			     xcel  xdvf  xflz  xhct  xitn  xkkh  xmbb  xnrv
# xans			     xcem  xdvg  xfma  xhcu  xito  xkki  xmbc  xnrw
# xant			     xcen  xdvh  xfmb  xhcv  xitp  xkkj  xmbd  xnrx
# xanu			     xceo  xdvi  xfmc  xhcw  xitq  xkkk  xmbe  xnry
# xanv			     xcep  xdvj  xfmd  xhcx  xitr  xkkl  xmbf  xnrz
# xanw			     xceq  xdvk  xfme  xhcy  xits  xkkm  xmbg  xnsa
# xanx			     xcer  xdvl  xfmf  xhcz  xitt  xkkn  xmbh  xnsb
# xany			     xces  xdvm  xfmg  xhda  xitu  xkko  xmbi  xnsc
# xanz			     xcet  xdvn  xfmh  xhdb  xitv  xkkp  xmbj  xnsd
# xaoa			     xceu  xdvo  xfmi  xhdc  xitw  xkkq  xmbk  xnse
# xaob			     xcev  xdvp  xfmj  xhdd  xitx  xkkr  xmbl  xnsf
# xaoc			     xcew  xdvq  xfmk  xhde  xity  xkks  xmbm  xnsg
# xaod			     xcex  xdvr  xfml  xhdf  xitz  xkkt  xmbn  xnsh
# xaoe			     xcey  xdvs  xfmm  xhdg  xiua  xkku  xmbo  xnsi
# xaof			     xcez  xdvt  xfmn  xhdh  xiub  xkkv  xmbp  xnsj
# xaog			     xcfa  xdvu  xfmo  xhdi  xiuc  xkkw  xmbq  xnsk
# xaoh			     xcfb  xdvv  xfmp  xhdj  xiud  xkkx  xmbr  xnsl
# xaoi			     xcfc  xdvw  xfmq  xhdk  xiue  xkky  xmbs  xnsm
# xaoj			     xcfd  xdvx  xfmr  xhdl  xiuf  xkkz  xmbt  xnsn
# xaok			     xcfe  xdvy  xfms  xhdm  xiug  xkla  xmbu  xnso
# xaol			     xcff  xdvz  xfmt  xhdn  xiuh  xklb  xmbv  xnsp
# xaom			     xcfg  xdwa  xfmu  xhdo  xiui  xklc  xmbw  xnsq
# xaon			     xcfh  xdwb  xfmv  xhdp  xiuj  xkld  xmbx  xnsr
# xaoo			     xcfi  xdwc  xfmw  xhdq  xiuk  xkle  xmby  xnss
# xaop			     xcfj  xdwd  xfmx  xhdr  xiul  xklf  xmbz  xnst
# xaoq			     xcfk  xdwe  xfmy  xhds  xium  xklg  xmca  xnsu
# xaor			     xcfl  xdwf  xfmz  xhdt  xiun  xklh  xmcb  xnsv
# xaos			     xcfm  xdwg  xfna  xhdu  xiuo  xkli  xmcc  xnsw
# xaot			     xcfn  xdwh  xfnb  xhdv  xiup  xklj  xmcd  xnsx
# xaou			     xcfo  xdwi  xfnc  xhdw  xiuq  xklk  xmce  xnsy
# xaov			     xcfp  xdwj  xfnd  xhdx  xiur  xkll  xmcf  xnsz
# xaow			     xcfq  xdwk  xfne  xhdy  xius  xklm  xmcg  xnta
# xaox			     xcfr  xdwl  xfnf  xhdz  xiut  xkln  xmch  xntb
# xaoy			     xcfs  xdwm  xfng  xhea  xiuu  xklo  xmci  xntc
# xaoz			     xcft  xdwn  xfnh  xheb  xiuv  xklp  xmcj  xntd
# xapa			     xcfu  xdwo  xfni  xhec  xiuw  xklq  xmck  xnte
# xapb			     xcfv  xdwp  xfnj  xhed  xiux  xklr  xmcl  xntf
# xapc			     xcfw  xdwq  xfnk  xhee  xiuy  xkls  xmcm  xntg
# xapd			     xcfx  xdwr  xfnl  xhef  xiuz  xklt  xmcn  xnth
# xape			     xcfy  xdws  xfnm  xheg  xiva  xklu  xmco  xnti
# xapf			     xcfz  xdwt  xfnn  xheh  xivb  xklv  xmcp  xntj
# xapg			     xcga  xdwu  xfno  xhei  xivc  xklw  xmcq  xntk
# xaph			     xcgb  xdwv  xfnp  xhej  xivd  xklx  xmcr  xntl
# xapi			     xcgc  xdww  xfnq  xhek  xive  xkly  xmcs  xntm
# xapj			     xcgd  xdwx  xfnr  xhel  xivf  xklz  xmct  xntn
# xapk			     xcge  xdwy  xfns  xhem  xivg  xkma  xmcu  xnto
# xapl			     xcgf  xdwz  xfnt  xhen  xivh  xkmb  xmcv  xntp
# xapm			     xcgg  xdxa  xfnu  xheo  xivi  xkmc  xmcw  xntq
# xapn			     xcgh  xdxb  xfnv  xhep  xivj  xkmd  xmcx  xntr
# xapo			     xcgi  xdxc  xfnw  xheq  xivk  xkme  xmcy  xnts
# xapp			     xcgj  xdxd  xfnx  xher  xivl  xkmf  xmcz  xntt
# xapq			     xcgk  xdxe  xfny  xhes  xivm  xkmg  xmda  xntu
# xapr			     xcgl  xdxf  xfnz  xhet  xivn  xkmh  xmdb  xntv
# xaps			     xcgm  xdxg  xfoa  xheu  xivo  xkmi  xmdc  xntw
# xapt			     xcgn  xdxh  xfob  xhev  xivp  xkmj  xmdd  xntx
# xapu			     xcgo  xdxi  xfoc  xhew  xivq  xkmk  xmde  xnty
# xapv			     xcgp  xdxj  xfod  xhex  xivr  xkml  xmdf  xntz
# xapw			     xcgq  xdxk  xfoe  xhey  xivs  xkmm  xmdg  xnua
# xapx			     xcgr  xdxl  xfof  xhez  xivt  xkmn  xmdh  xnub
# xapy			     xcgs  xdxm  xfog  xhfa  xivu  xkmo  xmdi  xnuc
# xapz			     xcgt  xdxn  xfoh  xhfb  xivv  xkmp  xmdj  xnud
# xaqa			     xcgu  xdxo  xfoi  xhfc  xivw  xkmq  xmdk  xnue
# xaqb			     xcgv  xdxp  xfoj  xhfd  xivx  xkmr  xmdl  xnuf
# xaqc			     xcgw  xdxq  xfok  xhfe  xivy  xkms  xmdm  xnug
# xaqd			     xcgx  xdxr  xfol  xhff  xivz  xkmt  xmdn  xnuh
# xaqe			     xcgy  xdxs  xfom  xhfg  xiwa  xkmu  xmdo  xnui
# xaqf			     xcgz  xdxt  xfon  xhfh  xiwb  xkmv  xmdp  xnuj
# xaqg			     xcha  xdxu  xfoo  xhfi  xiwc  xkmw  xmdq  xnuk
# xaqh			     xchb  xdxv  xfop  xhfj  xiwd  xkmx  xmdr  xnul
# xaqi			     xchc  xdxw  xfoq  xhfk  xiwe  xkmy  xmds  xnum
# xaqj			     xchd  xdxx  xfor  xhfl  xiwf  xkmz  xmdt  xnun
# xaqk			     xche  xdxy  xfos  xhfm  xiwg  xkna  xmdu  xnuo
# xaql			     xchf  xdxz  xfot  xhfn  xiwh  xknb  xmdv  xnup
# xaqm			     xchg  xdya  xfou  xhfo  xiwi  xknc  xmdw  xnuq
# xaqn			     xchh  xdyb  xfov  xhfp  xiwj  xknd  xmdx  xnur
# xaqo			     xchi  xdyc  xfow  xhfq  xiwk  xkne  xmdy  xnus
# xaqp			     xchj  xdyd  xfox  xhfr  xiwl  xknf  xmdz  xnut
# xaqq			     xchk  xdye  xfoy  xhfs  xiwm  xkng  xmea  xnuu
# xaqr			     xchl  xdyf  xfoz  xhft  xiwn  xknh  xmeb  xnuv
# xaqs			     xchm  xdyg  xfpa  xhfu  xiwo  xkni  xmec  xnuw
# xaqt			     xchn  xdyh  xfpb  xhfv  xiwp  xknj  xmed  xnux
# xaqu			     xcho  xdyi  xfpc  xhfw  xiwq  xknk  xmee  xnuy
# xaqv			     xchp  xdyj  xfpd  xhfx  xiwr  xknl  xmef  xnuz
# xaqw			     xchq  xdyk  xfpe  xhfy  xiws  xknm  xmeg  xnva
# xaqx			     xchr  xdyl  xfpf  xhfz  xiwt  xknn  xmeh  xnvb
# xaqy			     xchs  xdym  xfpg  xhga  xiwu  xkno  xmei  xnvc
# xaqz			     xcht  xdyn  xfph  xhgb  xiwv  xknp  xmej  xnvd
# xara			     xchu  xdyo  xfpi  xhgc  xiww  xknq  xmek  xnve
# xarb			     xchv  xdyp  xfpj  xhgd  xiwx  xknr  xmel  xnvf
# xarc			     xchw  xdyq  xfpk  xhge  xiwy  xkns  xmem  xnvg
# xard			     xchx  xdyr  xfpl  xhgf  xiwz  xknt  xmen  xnvh
# xare			     xchy  xdys  xfpm  xhgg  xixa  xknu  xmeo  xnvi
# xarf			     xchz  xdyt  xfpn  xhgh  xixb  xknv  xmep  xnvj
# xarg			     xcia  xdyu  xfpo  xhgi  xixc  xknw  xmeq  xnvk
# xarh			     xcib  xdyv  xfpp  xhgj  xixd  xknx  xmer  xnvl
# xari			     xcic  xdyw  xfpq  xhgk  xixe  xkny  xmes  xnvm
# xarj			     xcid  xdyx  xfpr  xhgl  xixf  xknz  xmet  xnvn
# xark			     xcie  xdyy  xfps  xhgm  xixg  xkoa  xmeu  xnvo
# xarl			     xcif  xdyz  xfpt  xhgn  xixh  xkob  xmev  xnvp
# xarm			     xcig  xdza  xfpu  xhgo  xixi  xkoc  xmew  xnvq
# xarn			     xcih  xdzb  xfpv  xhgp  xixj  xkod  xmex  xnvr
# xaro			     xcii  xdzc  xfpw  xhgq  xixk  xkoe  xmey  xnvs
# xarp			     xcij  xdzd  xfpx  xhgr  xixl  xkof  xmez  xnvt
# xarq			     xcik  xdze  xfpy  xhgs  xixm  xkog  xmfa  xnvu
# xarr			     xcil  xdzf  xfpz  xhgt  xixn  xkoh  xmfb  xnvv
# xars			     xcim  xdzg  xfqa  xhgu  xixo  xkoi  xmfc  xnvw
# xart			     xcin  xdzh  xfqb  xhgv  xixp  xkoj  xmfd  xnvx
# xaru			     xcio  xdzi  xfqc  xhgw  xixq  xkok  xmfe  xnvy
# xarv			     xcip  xdzj  xfqd  xhgx  xixr  xkol  xmff  xnvz
# xarw			     xciq  xdzk  xfqe  xhgy  xixs  xkom  xmfg  xnwa
# xarx			     xcir  xdzl  xfqf  xhgz  xixt  xkon  xmfh  xnwb
# xary			     xcis  xdzm  xfqg  xhha  xixu  xkoo  xmfi  xnwc
# xarz			     xcit  xdzn  xfqh  xhhb  xixv  xkop  xmfj  xnwd
# xasa			     xciu  xdzo  xfqi  xhhc  xixw  xkoq  xmfk  xnwe
# xasb			     xciv  xdzp  xfqj  xhhd  xixx  xkor  xmfl  xnwf
# xasc			     xciw  xdzq  xfqk  xhhe  xixy  xkos  xmfm  xnwg
# xasd			     xcix  xdzr  xfql  xhhf  xixz  xkot  xmfn  xnwh
# xase			     xciy  xdzs  xfqm  xhhg  xiya  xkou  xmfo  xnwi
# xasf			     xciz  xdzt  xfqn  xhhh  xiyb  xkov  xmfp  xnwj
# xasg			     xcja  xdzu  xfqo  xhhi  xiyc  xkow  xmfq  xnwk
# xash			     xcjb  xdzv  xfqp  xhhj  xiyd  xkox  xmfr  xnwl
# xasi			     xcjc  xdzw  xfqq  xhhk  xiye  xkoy  xmfs  xnwm
# xasj			     xcjd  xdzx  xfqr  xhhl  xiyf  xkoz  xmft  xnwn
# xask			     xcje  xdzy  xfqs  xhhm  xiyg  xkpa  xmfu  xnwo
# xasl			     xcjf  xdzz  xfqt  xhhn  xiyh  xkpb  xmfv  xnwp
# xasm			     xcjg  xeaa  xfqu  xhho  xiyi  xkpc  xmfw  xnwq
# xasn			     xcjh  xeab  xfqv  xhhp  xiyj  xkpd  xmfx  xnwr
# xaso			     xcji  xeac  xfqw  xhhq  xiyk  xkpe  xmfy  xnws
# xasp			     xcjj  xead  xfqx  xhhr  xiyl  xkpf  xmfz  xnwt
# xasq			     xcjk  xeae  xfqy  xhhs  xiym  xkpg  xmga  xnwu
# xasr			     xcjl  xeaf  xfqz  xhht  xiyn  xkph  xmgb  xnwv
# xass			     xcjm  xeag  xfra  xhhu  xiyo  xkpi  xmgc  xnww
# xast			     xcjn  xeah  xfrb  xhhv  xiyp  xkpj  xmgd  xnwx
# xasu			     xcjo  xeai  xfrc  xhhw  xiyq  xkpk  xmge  xnwy
# xasv			     xcjp  xeaj  xfrd  xhhx  xiyr  xkpl  xmgf  xnwz
# xasw			     xcjq  xeak  xfre  xhhy  xiys  xkpm  xmgg  xnxa
# xasx			     xcjr  xeal  xfrf  xhhz  xiyt  xkpn  xmgh  xnxb
# xasy			     xcjs  xeam  xfrg  xhia  xiyu  xkpo  xmgi  xnxc
# xasz			     xcjt  xean  xfrh  xhib  xiyv  xkpp  xmgj  xnxd
# xata			     xcju  xeao  xfri  xhic  xiyw  xkpq  xmgk  xnxe
# xatb			     xcjv  xeap  xfrj  xhid  xiyx  xkpr  xmgl  xnxf
# xatc			     xcjw  xeaq  xfrk  xhie  xiyy  xkps  xmgm  xnxg
# xatd			     xcjx  xear  xfrl  xhif  xiyz  xkpt  xmgn  xnxh
# xate			     xcjy  xeas  xfrm  xhig  xiza  xkpu  xmgo  xnxi
# xatf			     xcjz  xeat  xfrn  xhih  xizb  xkpv  xmgp  xnxj
# xatg			     xcka  xeau  xfro  xhii  xizc  xkpw  xmgq  xnxk
# xath			     xckb  xeav  xfrp  xhij  xizd  xkpx  xmgr  xnxl
# xati			     xckc  xeaw  xfrq  xhik  xize  xkpy  xmgs  xnxm
# xatj			     xckd  xeax  xfrr  xhil  xizf  xkpz  xmgt  xnxn
# xatk			     xcke  xeay  xfrs  xhim  xizg  xkqa  xmgu  xnxo
# xatl			     xckf  xeaz  xfrt  xhin  xizh  xkqb  xmgv  xnxp
# xatm			     xckg  xeba  xfru  xhio  xizi  xkqc  xmgw  xnxq
# xatn			     xckh  xebb  xfrv  xhip  xizj  xkqd  xmgx  xnxr
# xato			     xcki  xebc  xfrw  xhiq  xizk  xkqe  xmgy  xnxs
# xatp			     xckj  xebd  xfrx  xhir  xizl  xkqf  xmgz  xnxt
# xatq			     xckk  xebe  xfry  xhis  xizm  xkqg  xmha  xnxu
# xatr			     xckl  xebf  xfrz  xhit  xizn  xkqh  xmhb  xnxv
# xats			     xckm  xebg  xfsa  xhiu  xizo  xkqi  xmhc  xnxw
# xatt			     xckn  xebh  xfsb  xhiv  xizp  xkqj  xmhd  xnxx
# xatu			     xcko  xebi  xfsc  xhiw  xizq  xkqk  xmhe  xnxy
# xatv			     xckp  xebj  xfsd  xhix  xizr  xkql  xmhf  xnxz
# xatw			     xckq  xebk  xfse  xhiy  xizs  xkqm  xmhg  xnya
# xatx			     xckr  xebl  xfsf  xhiz  xizt  xkqn  xmhh  xnyb
# xaty			     xcks  xebm  xfsg  xhja  xizu  xkqo  xmhi  xnyc
# xatz			     xckt  xebn  xfsh  xhjb  xizv  xkqp  xmhj  xnyd
# xaua			     xcku  xebo  xfsi  xhjc  xizw  xkqq  xmhk  xnye
# xaub			     xckv  xebp  xfsj  xhjd  xizx  xkqr  xmhl  xnyf
# xauc			     xckw  xebq  xfsk  xhje  xizy  xkqs  xmhm  xnyg
# xaud			     xckx  xebr  xfsl  xhjf  xizz  xkqt  xmhn  xnyh
# xaue			     xcky  xebs  xfsm  xhjg  xjaa  xkqu  xmho  xnyi
# xauf			     xckz  xebt  xfsn  xhjh  xjab  xkqv  xmhp  xnyj
# xaug			     xcla  xebu  xfso  xhji  xjac  xkqw  xmhq  xnyk
# xauh			     xclb  xebv  xfsp  xhjj  xjad  xkqx  xmhr  xnyl
# xaui			     xclc  xebw  xfsq  xhjk  xjae  xkqy  xmhs  xnym
# xauj			     xcld  xebx  xfsr  xhjl  xjaf  xkqz  xmht  xnyn
# xauk			     xcle  xeby  xfss  xhjm  xjag  xkra  xmhu  xnyo
# xaul			     xclf  xebz  xfst  xhjn  xjah  xkrb  xmhv  xnyp
# xaum			     xclg  xeca  xfsu  xhjo  xjai  xkrc  xmhw  xnyq
# xaun			     xclh  xecb  xfsv  xhjp  xjaj  xkrd  xmhx  xnyr
# xauo			     xcli  xecc  xfsw  xhjq  xjak  xkre  xmhy  xnys
# xaup			     xclj  xecd  xfsx  xhjr  xjal  xkrf  xmhz  xnyt
# xauq			     xclk  xece  xfsy  xhjs  xjam  xkrg  xmia  xnyu
# xaur			     xcll  xecf  xfsz  xhjt  xjan  xkrh  xmib  xnyv
# xaus			     xclm  xecg  xfta  xhju  xjao  xkri  xmic  xnyw
# xaut			     xcln  xech  xftb  xhjv  xjap  xkrj  xmid  xnyx
# xauu			     xclo  xeci  xftc  xhjw  xjaq  xkrk  xmie  xnyy
# xauv			     xclp  xecj  xftd  xhjx  xjar  xkrl  xmif  xnyz
# xauw			     xclq  xeck  xfte  xhjy  xjas  xkrm  xmig  xnza
# xaux			     xclr  xecl  xftf  xhjz  xjat  xkrn  xmih  xnzb
# xauy			     xcls  xecm  xftg  xhka  xjau  xkro  xmii  xnzc
# xauz			     xclt  xecn  xfth  xhkb  xjav  xkrp  xmij  xnzd
# xava			     xclu  xeco  xfti  xhkc  xjaw  xkrq  xmik  xnze
# xavb			     xclv  xecp  xftj  xhkd  xjax  xkrr  xmil  xnzf
# xavc			     xclw  xecq  xftk  xhke  xjay  xkrs  xmim  xnzg
# xavd			     xclx  xecr  xftl  xhkf  xjaz  xkrt  xmin  xnzh
# xave			     xcly  xecs  xftm  xhkg  xjba  xkru  xmio  xnzi
# xavf			     xclz  xect  xftn  xhkh  xjbb  xkrv  xmip  xnzj
# xavg			     xcma  xecu  xfto  xhki  xjbc  xkrw  xmiq  xnzk
# xavh			     xcmb  xecv  xftp  xhkj  xjbd  xkrx  xmir  xnzl
# xavi			     xcmc  xecw  xftq  xhkk  xjbe  xkry  xmis  xnzm
# xavj			     xcmd  xecx  xftr  xhkl  xjbf  xkrz  xmit  xnzn
# xavk			     xcme  xecy  xfts  xhkm  xjbg  xksa  xmiu  xnzo
# xavl			     xcmf  xecz  xftt  xhkn  xjbh  xksb  xmiv  xnzp
# xavm			     xcmg  xeda  xftu  xhko  xjbi  xksc  xmiw  xnzq
# xavn			     xcmh  xedb  xftv  xhkp  xjbj  xksd  xmix  xnzr
# xavo			     xcmi  xedc  xftw  xhkq  xjbk  xkse  xmiy  xnzs
# xavp			     xcmj  xedd  xftx  xhkr  xjbl  xksf  xmiz  xnzt
# xavq			     xcmk  xede  xfty  xhks  xjbm  xksg  xmja  xnzu
# xavr			     xcml  xedf  xftz  xhkt  xjbn  xksh  xmjb  xnzv
# xavs			     xcmm  xedg  xfua  xhku  xjbo  xksi  xmjc  xnzw
# xavt			     xcmn  xedh  xfub  xhkv  xjbp  xksj  xmjd  xnzx
# xavu			     xcmo  xedi  xfuc  xhkw  xjbq  xksk  xmje  xnzy
# xavv			     xcmp  xedj  xfud  xhkx  xjbr  xksl  xmjf  xnzz
# xavw			     xcmq  xedk  xfue  xhky  xjbs  xksm  xmjg  xoaa
# xavx			     xcmr  xedl  xfuf  xhkz  xjbt  xksn  xmjh  xoab
# xavy			     xcms  xedm  xfug  xhla  xjbu  xkso  xmji  xoac
# xavz			     xcmt  xedn  xfuh  xhlb  xjbv  xksp  xmjj  xoad
# xawa			     xcmu  xedo  xfui  xhlc  xjbw  xksq  xmjk  xoae
# xawb			     xcmv  xedp  xfuj  xhld  xjbx  xksr  xmjl  xoaf
# xawc			     xcmw  xedq  xfuk  xhle  xjby  xkss  xmjm  xoag
# xawd			     xcmx  xedr  xful  xhlf  xjbz  xkst  xmjn  xoah
# xawe			     xcmy  xeds  xfum  xhlg  xjca  xksu  xmjo  xoai
# xawf			     xcmz  xedt  xfun  xhlh  xjcb  xksv  xmjp  xoaj
# xawg			     xcna  xedu  xfuo  xhli  xjcc  xksw  xmjq  xoak
# xawh			     xcnb  xedv  xfup  xhlj  xjcd  xksx  xmjr  xoal
# xawi			     xcnc  xedw  xfuq  xhlk  xjce  xksy  xmjs  xoam
# xawj			     xcnd  xedx  xfur  xhll  xjcf  xksz  xmjt  xoan
# xawk			     xcne  xedy  xfus  xhlm  xjcg  xkta  xmju  xoao
# xawl			     xcnf  xedz  xfut  xhln  xjch  xktb  xmjv  xoap
# xawm			     xcng  xeea  xfuu  xhlo  xjci  xktc  xmjw  xoaq
# xawn			     xcnh  xeeb  xfuv  xhlp  xjcj  xktd  xmjx  xoar
# xawo			     xcni  xeec  xfuw  xhlq  xjck  xkte  xmjy  xoas
# xawp			     xcnj  xeed  xfux  xhlr  xjcl  xktf  xmjz  xoat
# xawq			     xcnk  xeee  xfuy  xhls  xjcm  xktg  xmka  xoau
# xawr			     xcnl  xeef  xfuz  xhlt  xjcn  xkth  xmkb  xoav
# xaws			     xcnm  xeeg  xfva  xhlu  xjco  xkti  xmkc  xoaw
# xawt			     xcnn  xeeh  xfvb  xhlv  xjcp  xktj  xmkd  xoax
# xawu			     xcno  xeei  xfvc  xhlw  xjcq  xktk  xmke  xoay
# xawv			     xcnp  xeej  xfvd  xhlx  xjcr  xktl  xmkf  xoaz
# xaww			     xcnq  xeek  xfve  xhly  xjcs  xktm  xmkg  xoba
# xawx			     xcnr  xeel  xfvf  xhlz  xjct  xktn  xmkh  xobb
# xawy			     xcns  xeem  xfvg  xhma  xjcu  xkto  xmki  xobc
# xawz			     xcnt  xeen  xfvh  xhmb  xjcv  xktp  xmkj  xobd
# xaxa			     xcnu  xeeo  xfvi  xhmc  xjcw  xktq  xmkk  xobe
# xaxb			     xcnv  xeep  xfvj  xhmd  xjcx  xktr  xmkl  xobf
# xaxc			     xcnw  xeeq  xfvk  xhme  xjcy  xkts  xmkm  xobg
# xaxd			     xcnx  xeer  xfvl  xhmf  xjcz  xktt  xmkn  xobh
# xaxe			     xcny  xees  xfvm  xhmg  xjda  xktu  xmko  xobi
# xaxf			     xcnz  xeet  xfvn  xhmh  xjdb  xktv  xmkp  xobj
# xaxg			     xcoa  xeeu  xfvo  xhmi  xjdc  xktw  xmkq  xobk
# xaxh			     xcob  xeev  xfvp  xhmj  xjdd  xktx  xmkr  xobl
# xaxi			     xcoc  xeew  xfvq  xhmk  xjde  xkty  xmks  xobm
# xaxj			     xcod  xeex  xfvr  xhml  xjdf  xktz  xmkt  xobn
# xaxk			     xcoe  xeey  xfvs  xhmm  xjdg  xkua  xmku  xobo
# xaxl			     xcof  xeez  xfvt  xhmn  xjdh  xkub  xmkv  xobp
# xaxm			     xcog  xefa  xfvu  xhmo  xjdi  xkuc  xmkw  xobq
# xaxn			     xcoh  xefb  xfvv  xhmp  xjdj  xkud  xmkx  xobr
# xaxo			     xcoi  xefc  xfvw  xhmq  xjdk  xkue  xmky  xobs
# xaxp			     xcoj  xefd  xfvx  xhmr  xjdl  xkuf  xmkz  xobt
# xaxq			     xcok  xefe  xfvy  xhms  xjdm  xkug  xmla  xobu
# xaxr			     xcol  xeff  xfvz  xhmt  xjdn  xkuh  xmlb  xobv
# xaxs			     xcom  xefg  xfwa  xhmu  xjdo  xkui  xmlc  xobw
# xaxt			     xcon  xefh  xfwb  xhmv  xjdp  xkuj  xmld  xobx
# xaxu			     xcoo  xefi  xfwc  xhmw  xjdq  xkuk  xmle  xoby
# xaxv			     xcop  xefj  xfwd  xhmx  xjdr  xkul  xmlf  xobz
# xaxw			     xcoq  xefk  xfwe  xhmy  xjds  xkum  xmlg  xoca
# xaxx			     xcor  xefl  xfwf  xhmz  xjdt  xkun  xmlh  xocb
# xaxy			     xcos  xefm  xfwg  xhna  xjdu  xkuo  xmli  xocc
# xaxz			     xcot  xefn  xfwh  xhnb  xjdv  xkup  xmlj  xocd
# xaya			     xcou  xefo  xfwi  xhnc  xjdw  xkuq  xmlk  xoce
# xayb			     xcov  xefp  xfwj  xhnd  xjdx  xkur  xmll  xocf
# xayc			     xcow  xefq  xfwk  xhne  xjdy  xkus  xmlm  xocg
# xayd			     xcox  xefr  xfwl  xhnf  xjdz  xkut  xmln  xoch
# xaye			     xcoy  xefs  xfwm  xhng  xjea  xkuu  xmlo  xoci
# xayf			     xcoz  xeft  xfwn  xhnh  xjeb  xkuv  xmlp  xocj
# xayg			     xcpa  xefu  xfwo  xhni  xjec  xkuw  xmlq  xock
# xayh			     xcpb  xefv  xfwp  xhnj  xjed  xkux  xmlr  xocl
# xayi			     xcpc  xefw  xfwq  xhnk  xjee  xkuy  xmls  xocm
# xayj			     xcpd  xefx  xfwr  xhnl  xjef  xkuz  xmlt  xocn
# xayk			     xcpe  xefy  xfws  xhnm  xjeg  xkva  xmlu  xoco
# xayl			     xcpf  xefz  xfwt  xhnn  xjeh  xkvb  xmlv  xocp
# xaym			     xcpg  xega  xfwu  xhno  xjei  xkvc  xmlw  xocq
# xayn			     xcph  xegb  xfwv  xhnp  xjej  xkvd  xmlx  xocr
# xayo			     xcpi  xegc  xfww  xhnq  xjek  xkve  xmly  xocs
# xayp			     xcpj  xegd  xfwx  xhnr  xjel  xkvf  xmlz  xoct
# xayq			     xcpk  xege  xfwy  xhns  xjem  xkvg  xmma  xocu
# xayr			     xcpl  xegf  xfwz  xhnt  xjen  xkvh  xmmb  xocv
# xays			     xcpm  xegg  xfxa  xhnu  xjeo  xkvi  xmmc  xocw
# xayt			     xcpn  xegh  xfxb  xhnv  xjep  xkvj  xmmd  xocx
# xayu			     xcpo  xegi  xfxc  xhnw  xjeq  xkvk  xmme  xocy
# xayv			     xcpp  xegj  xfxd  xhnx  xjer  xkvl  xmmf  xocz
# xayw			     xcpq  xegk  xfxe  xhny  xjes  xkvm  xmmg  xoda
# xayx			     xcpr  xegl  xfxf  xhnz  xjet  xkvn  xmmh  xodb
# xayy			     xcps  xegm  xfxg  xhoa  xjeu  xkvo  xmmi  xodc
# xayz			     xcpt  xegn  xfxh  xhob  xjev  xkvp  xmmj  xodd
# xaza			     xcpu  xego  xfxi  xhoc  xjew  xkvq  xmmk  xode
# xazb			     xcpv  xegp  xfxj  xhod  xjex  xkvr  xmml  xodf
# xazc			     xcpw  xegq  xfxk  xhoe  xjey  xkvs  xmmm  xodg
# xazd			     xcpx  xegr  xfxl  xhof  xjez  xkvt  xmmn  xodh
# xaze			     xcpy  xegs  xfxm  xhog  xjfa  xkvu  xmmo  xodi
# xazf			     xcpz  xegt  xfxn  xhoh  xjfb  xkvv  xmmp  xodj
# xazg			     xcqa  xegu  xfxo  xhoi  xjfc  xkvw  xmmq  xodk
# xazh			     xcqb  xegv  xfxp  xhoj  xjfd  xkvx  xmmr  xodl
# xazi			     xcqc  xegw  xfxq  xhok  xjfe  xkvy  xmms  xodm
# xazj			     xcqd  xegx  xfxr  xhol  xjff  xkvz  xmmt  xodn
# xazk			     xcqe  xegy  xfxs  xhom  xjfg  xkwa  xmmu  xodo
# xazl			     xcqf  xegz  xfxt  xhon  xjfh  xkwb  xmmv  xodp
# xazm			     xcqg  xeha  xfxu  xhoo  xjfi  xkwc  xmmw  xodq
# xazn			     xcqh  xehb  xfxv  xhop  xjfj  xkwd  xmmx  xodr
# xazo			     xcqi  xehc  xfxw  xhoq  xjfk  xkwe  xmmy  xods
# xazp			     xcqj  xehd  xfxx  xhor  xjfl  xkwf  xmmz  xodt
# xazq			     xcqk  xehe  xfxy  xhos  xjfm  xkwg  xmna  xodu
# xazr			     xcql  xehf  xfxz  xhot  xjfn  xkwh  xmnb  xodv
# xazs			     xcqm  xehg  xfya  xhou  xjfo  xkwi  xmnc  xodw
# xazt			     xcqn  xehh  xfyb  xhov  xjfp  xkwj  xmnd  xodx
# xazu			     xcqo  xehi  xfyc  xhow  xjfq  xkwk  xmne  xody
# xazv			     xcqp  xehj  xfyd  xhox  xjfr  xkwl  xmnf  xodz
# xazw			     xcqq  xehk  xfye  xhoy  xjfs  xkwm  xmng  xoea
# xazx			     xcqr  xehl  xfyf  xhoz  xjft  xkwn  xmnh  xoeb
# xazy			     xcqs  xehm  xfyg  xhpa  xjfu  xkwo  xmni  xoec
# xazz			     xcqt  xehn  xfyh  xhpb  xjfv  xkwp  xmnj  xoed
# xbaa			     xcqu  xeho  xfyi  xhpc  xjfw  xkwq  xmnk  xoee
# xbab			     xcqv  xehp  xfyj  xhpd  xjfx  xkwr  xmnl  xoef
# xbac			     xcqw  xehq  xfyk  xhpe  xjfy  xkws  xmnm  xoeg
# xbad			     xcqx  xehr  xfyl  xhpf  xjfz  xkwt  xmnn  xoeh
# xbae			     xcqy  xehs  xfym  xhpg  xjga  xkwu  xmno  xoei
# xbaf			     xcqz  xeht  xfyn  xhph  xjgb  xkwv  xmnp  xoej
# xbag			     xcra  xehu  xfyo  xhpi  xjgc  xkww  xmnq  xoek
# xbah			     xcrb  xehv  xfyp  xhpj  xjgd  xkwx  xmnr  xoel
# xbai			     xcrc  xehw  xfyq  xhpk  xjge  xkwy  xmns  xoem
# xbaj			     xcrd  xehx  xfyr  xhpl  xjgf  xkwz  xmnt  xoen
# xbak			     xcre  xehy  xfys  xhpm  xjgg  xkxa  xmnu  xoeo
# xbal			     xcrf  xehz  xfyt  xhpn  xjgh  xkxb  xmnv  xoep
# xbam			     xcrg  xeia  xfyu  xhpo  xjgi  xkxc  xmnw  xoeq
# xban			     xcrh  xeib  xfyv  xhpp  xjgj  xkxd  xmnx  xoer
# xbao			     xcri  xeic  xfyw  xhpq  xjgk  xkxe  xmny  xoes
# xbap			     xcrj  xeid  xfyx  xhpr  xjgl  xkxf  xmnz  xoet
# xbaq			     xcrk  xeie  xfyy  xhps  xjgm  xkxg  xmoa  xoeu
# xbar			     xcrl  xeif  xfyz  xhpt  xjgn  xkxh  xmob  xoev
# xbas			     xcrm  xeig  xfza  xhpu  xjgo  xkxi  xmoc  xoew
# xbat			     xcrn  xeih  xfzb  xhpv  xjgp  xkxj  xmod  xoex
# xbau			     xcro  xeii  xfzc  xhpw  xjgq  xkxk  xmoe  xoey
# xbav			     xcrp  xeij  xfzd  xhpx  xjgr  xkxl  xmof  xoez
# xbaw			     xcrq  xeik  xfze  xhpy  xjgs  xkxm  xmog  xofa
# xbax			     xcrr  xeil  xfzf  xhpz  xjgt  xkxn  xmoh  xofb
# xbay			     xcrs  xeim  xfzg  xhqa  xjgu  xkxo  xmoi  xofc
# xbaz			     xcrt  xein  xfzh  xhqb  xjgv  xkxp  xmoj  xofd
# xbba			     xcru  xeio  xfzi  xhqc  xjgw  xkxq  xmok  xofe
# xbbb			     xcrv  xeip  xfzj  xhqd  xjgx  xkxr  xmol  xoff
# xbbc			     xcrw  xeiq  xfzk  xhqe  xjgy  xkxs  xmom  xofg
# xbbd			     xcrx  xeir  xfzl  xhqf  xjgz  xkxt  xmon  xofh
# xbbe			     xcry  xeis  xfzm  xhqg  xjha  xkxu  xmoo  xofi
# xbbf			     xcrz  xeit  xfzn  xhqh  xjhb  xkxv  xmop  xofj
# xbbg			     xcsa  xeiu  xfzo  xhqi  xjhc  xkxw  xmoq  xofk
# xbbh			     xcsb  xeiv  xfzp  xhqj  xjhd  xkxx  xmor  xofl
# xbbi			     xcsc  xeiw  xfzq  xhqk  xjhe  xkxy  xmos  xofm
# xbbj			     xcsd  xeix  xfzr  xhql  xjhf  xkxz  xmot  xofn
# xbbk			     xcse  xeiy  xfzs  xhqm  xjhg  xkya  xmou  xofo
# xbbl			     xcsf  xeiz  xfzt  xhqn  xjhh  xkyb  xmov  xofp
# xbbm			     xcsg  xeja  xfzu  xhqo  xjhi  xkyc  xmow  xofq
# xbbn			     xcsh  xejb  xfzv  xhqp  xjhj  xkyd  xmox  xofr
# xbbo			     xcsi  xejc  xfzw  xhqq  xjhk  xkye  xmoy  xofs
# xbbp			     xcsj  xejd  xfzx  xhqr  xjhl  xkyf  xmoz  xoft
# xbbq			     xcsk  xeje  xfzy  xhqs  xjhm  xkyg  xmpa  xofu
# xbbr			     xcsl  xejf  xfzz  xhqt  xjhn  xkyh  xmpb  xofv
# xbbs			     xcsm  xejg  xgaa  xhqu  xjho  xkyi  xmpc  xofw
# xbbt			     xcsn  xejh  xgab  xhqv  xjhp  xkyj  xmpd  xofx
# xbbu			     xcso  xeji  xgac  xhqw  xjhq  xkyk  xmpe  xofy
# xbbv			     xcsp  xejj  xgad  xhqx  xjhr  xkyl  xmpf  xofz
# xbbw			     xcsq  xejk  xgae  xhqy  xjhs  xkym  xmpg  xoga
# xbbx			     xcsr  xejl  xgaf  xhqz  xjht  xkyn  xmph  xogb
# xbby			     xcss  xejm  xgag  xhra  xjhu  xkyo  xmpi  xogc
# xbbz			     xcst  xejn  xgah  xhrb  xjhv  xkyp  xmpj  xogd
# xbca			     xcsu  xejo  xgai  xhrc  xjhw  xkyq  xmpk  xoge
# xbcb			     xcsv  xejp  xgaj  xhrd  xjhx  xkyr  xmpl  xogf
# xbcc			     xcsw  xejq  xgak  xhre  xjhy  xkys  xmpm  xogg
# xbcd			     xcsx  xejr  xgal  xhrf  xjhz  xkyt  xmpn  xogh
# xbce			     xcsy  xejs  xgam  xhrg  xjia  xkyu  xmpo  xogi
# xbcf			     xcsz  xejt  xgan  xhrh  xjib  xkyv  xmpp  xogj
# xbcg			     xcta  xeju  xgao  xhri  xjic  xkyw  xmpq  xogk
# xbch			     xctb  xejv  xgap  xhrj  xjid  xkyx  xmpr  xogl
# xbci			     xctc  xejw  xgaq  xhrk  xjie  xkyy  xmps  xogm
# xbcj			     xctd  xejx  xgar  xhrl  xjif  xkyz  xmpt  xogn
# xbck			     xcte  xejy  xgas  xhrm  xjig  xkza  xmpu  xogo
# xbcl			     xctf  xejz  xgat  xhrn  xjih  xkzb  xmpv  xogp
# xbcm			     xctg  xeka  xgau  xhro  xjii  xkzc  xmpw  xogq
# xbcn			     xcth  xekb  xgav  xhrp  xjij  xkzd  xmpx  xogr
# xbco			     xcti  xekc  xgaw  xhrq  xjik  xkze  xmpy  xogs
# xbcp			     xctj  xekd  xgax  xhrr  xjil  xkzf  xmpz  xogt
# xbcq			     xctk  xeke  xgay  xhrs  xjim  xkzg  xmqa  xogu
# xbcr			     xctl  xekf  xgaz  xhrt  xjin  xkzh  xmqb  xogv
# xbcs			     xctm  xekg  xgba  xhru  xjio  xkzi  xmqc  xogw
# xbct			     xctn  xekh  xgbb  xhrv  xjip  xkzj  xmqd  xogx
# xbcu			     xcto  xeki  xgbc  xhrw  xjiq  xkzk  xmqe  xogy
# xbcv			     xctp  xekj  xgbd  xhrx  xjir  xkzl  xmqf  xogz
# xbcw			     xctq  xekk  xgbe  xhry  xjis  xkzm  xmqg  xoha
# xbcx			     xctr  xekl  xgbf  xhrz  xjit  xkzn  xmqh  xohb
# xbcy			     xcts  xekm  xgbg  xhsa  xjiu  xkzo  xmqi  xohc
# xbcz			     xctt  xekn  xgbh  xhsb  xjiv  xkzp  xmqj  xohd
# xbda			     xctu  xeko  xgbi  xhsc  xjiw  xkzq  xmqk  xohe
# xbdb			     xctv  xekp  xgbj  xhsd  xjix  xkzr  xmql  xohf
# xbdc			     xctw  xekq  xgbk  xhse  xjiy  xkzs  xmqm  xohg
# xbdd			     xctx  xekr  xgbl  xhsf  xjiz  xkzt  xmqn  xohh
# xbde			     xcty  xeks  xgbm  xhsg  xjja  xkzu  xmqo  xohi
# xbdf			     xctz  xekt  xgbn  xhsh  xjjb  xkzv  xmqp  xohj
# xbdg			     xcua  xeku  xgbo  xhsi  xjjc  xkzw  xmqq  xohk
# xbdh			     xcub  xekv  xgbp  xhsj  xjjd  xkzx  xmqr  xohl
# xbdi			     xcuc  xekw  xgbq  xhsk  xjje  xkzy  xmqs  xohm
# xbdj			     xcud  xekx  xgbr  xhsl  xjjf  xkzz  xmqt  xohn
# xbdk			     xcue  xeky  xgbs  xhsm  xjjg  xlaa  xmqu  xoho
# xbdl			     xcuf  xekz  xgbt  xhsn  xjjh  xlab  xmqv  xohp
# xbdm			     xcug  xela  xgbu  xhso  xjji  xlac  xmqw  xohq
# xbdn			     xcuh  xelb  xgbv  xhsp  xjjj  xlad  xmqx  xohr
# xbdo			     xcui  xelc  xgbw  xhsq  xjjk  xlae  xmqy  xohs
# xbdp			     xcuj  xeld  xgbx  xhsr  xjjl  xlaf  xmqz  xoht
# xbdq			     xcuk  xele  xgby  xhss  xjjm  xlag  xmra  xohu
# xbdr			     xcul  xelf  xgbz  xhst  xjjn  xlah  xmrb  xohv
# xbds			     xcum  xelg  xgca  xhsu  xjjo  xlai  xmrc  xohw
# xbdt			     xcun  xelh  xgcb  xhsv  xjjp  xlaj  xmrd  xohx
# xbdu			     xcuo  xeli  xgcc  xhsw  xjjq  xlak  xmre  xohy
# xbdv			     xcup  xelj  xgcd  xhsx  xjjr  xlal  xmrf  xohz
# xbdw			     xcuq  xelk  xgce  xhsy  xjjs  xlam  xmrg  xoia
# xbdx			     xcur  xell  xgcf  xhsz  xjjt  xlan  xmrh  xoib
# xbdy			     xcus  xelm  xgcg  xhta  xjju  xlao  xmri  xoic
# xbdz			     xcut  xeln  xgch  xhtb  xjjv  xlap  xmrj  xoid
# xbea			     xcuu  xelo  xgci  xhtc  xjjw  xlaq  xmrk  xoie
# xbeb			     xcuv  xelp  xgcj  xhtd  xjjx  xlar  xmrl  xoif
# xbec			     xcuw  xelq  xgck  xhte  xjjy  xlas  xmrm  xoig
# xbed			     xcux  xelr  xgcl  xhtf  xjjz  xlat  xmrn  xoih
# xbee			     xcuy  xels  xgcm  xhtg  xjka  xlau  xmro  xoii
# xbef			     xcuz  xelt  xgcn  xhth  xjkb  xlav  xmrp  xoij
# xbeg			     xcva  xelu  xgco  xhti  xjkc  xlaw  xmrq  xoik
# xbeh			     xcvb  xelv  xgcp  xhtj  xjkd  xlax  xmrr  xoil
# xbei			     xcvc  xelw  xgcq  xhtk  xjke  xlay  xmrs  xoim
# xbej			     xcvd  xelx  xgcr  xhtl  xjkf  xlaz  xmrt  xoin
# xbek			     xcve  xely  xgcs  xhtm  xjkg  xlba  xmru  xoio
# xbel			     xcvf  xelz  xgct  xhtn  xjkh  xlbb  xmrv  xoip
# xbem			     xcvg  xema  xgcu  xhto  xjki  xlbc  xmrw  xoiq
# xben			     xcvh  xemb  xgcv  xhtp  xjkj  xlbd  xmrx  xoir
# xbeo			     xcvi  xemc  xgcw  xhtq  xjkk  xlbe  xmry  xois
# xbep			     xcvj  xemd  xgcx  xhtr  xjkl  xlbf  xmrz  xoit
# xbeq			     xcvk  xeme  xgcy  xhts  xjkm  xlbg  xmsa  xoiu
# xber			     xcvl  xemf  xgcz  xhtt  xjkn  xlbh  xmsb  xoiv
# xbes			     xcvm  xemg  xgda  xhtu  xjko  xlbi  xmsc  xoiw
# xbet			     xcvn  xemh  xgdb  xhtv  xjkp  xlbj  xmsd  xoix
# xbeu			     xcvo  xemi  xgdc  xhtw  xjkq  xlbk  xmse  xoiy
# xbev			     xcvp  xemj  xgdd  xhtx  xjkr  xlbl  xmsf  xoiz
# xbew			     xcvq  xemk  xgde  xhty  xjks  xlbm  xmsg  xoja
# xbex			     xcvr  xeml  xgdf  xhtz  xjkt  xlbn  xmsh  xojb
# xbey			     xcvs  xemm  xgdg  xhua  xjku  xlbo  xmsi  xojc
# ...
# xbgc			     xcww  xenq  xgek  xhve  xjly  xlcs  xmtm  xokg
# xbgd			     xcwx  xenr  xgel  xhvf  xjlz  xlct  xmtn  xokh
# xbge			     xcwy  xens  xgem  xhvg  xjma  xlcu  xmto  xoki
# xbgf			     xcwz  xent  xgen  xhvh  xjmb  xlcv  xmtp  xokj
# xbgg			     xcxa  xenu  xgeo  xhvi  xjmc  xlcw  xmtq  xokk
# xbgh			     xcxb  xenv  xgep  xhvj  xjmd  xlcx  xmtr  xokl
# xbgi			     xcxc  xenw  xgeq  xhvk  xjme  xlcy  xmts  xokm
# xbgj			     xcxd  xenx  xger  xhvl  xjmf  xlcz  xmtt  xokn
# xbgk			     xcxe  xeny  xges  xhvm  xjmg  xlda  xmtu  xoko
# xbgl			     xcxf  xenz  xget  xhvn  xjmh  xldb  xmtv  xokp
# xbgm			     xcxg  xeoa  xgeu  xhvo  xjmi  xldc  xmtw  xokq
# xbgn			     xcxh  xeob  xgev  xhvp  xjmj  xldd  xmtx  xokr
# xbgo			     xcxi  xeoc  xgew  xhvq  xjmk  xlde  xmty  xoks
# xbgp			     xcxj  xeod  xgex  xhvr  xjml  xldf  xmtz  xokt
# xbgq			     xcxk  xeoe  xgey  xhvs  xjmm  xldg  xmua  xoku
# xbgr			     xcxl  xeof  xgez  xhvt  xjmn  xldh  xmub  xokv
# xbgs			     xcxm  xeog  xgfa  xhvu  xjmo  xldi  xmuc  xokw
# xbgt			     xcxn  xeoh  xgfb  xhvv  xjmp  xldj  xmud  xokx
# xbgu			     xcxo  xeoi  xgfc  xhvw  xjmq  xldk  xmue  xoky
# xbgv			     xcxp  xeoj  xgfd  xhvx  xjmr  xldl  xmuf  xokz
# xbgw			     xcxq  xeok  xgfe  xhvy  xjms  xldm  xmug  xola
# xbgx			     xcxr  xeol  xgff  xhvz  xjmt  xldn  xmuh  xolb
# xbgy			     xcxs  xeom  xgfg  xhwa  xjmu  xldo  xmui  xolc
# xbgz			     xcxt  xeon  xgfh  xhwb  xjmv  xldp  xmuj  xold
# xbha			     xcxu  xeoo  xgfi  xhwc  xjmw  xldq  xmuk  xole
# xbhb			     xcxv  xeop  xgfj  xhwd  xjmx  xldr  xmul  xolf
# xbhc			     xcxw  xeoq  xgfk  xhwe  xjmy  xlds  xmum  xolg
# xbhd			     xcxx  xeor  xgfl  xhwf  xjmz  xldt  xmun  xolh
# xbhe			     xcxy  xeos  xgfm  xhwg  xjna  xldu  xmuo  xoli
# xbhf			     xcxz  xeot  xgfn  xhwh  xjnb  xldv  xmup  xolj
# xbhg			     xcya  xeou  xgfo  xhwi  xjnc  xldw  xmuq  xolk
# xbhh			     xcyb  xeov  xgfp  xhwj  xjnd  xldx  xmur  xoll
# xbhi			     xcyc  xeow  xgfq  xhwk  xjne  xldy  xmus  xolm
# xbhj			     xcyd  xeox  xgfr  xhwl  xjnf  xldz  xmut  xoln
# xbhk			     xcye  xeoy  xgfs  xhwm  xjng  xlea  xmuu  xolo
# xbhl			     xcyf  xeoz  xgft  xhwn  xjnh  xleb  xmuv  xolp
# xbhm			     xcyg  xepa  xgfu  xhwo  xjni  xlec  xmuw  xolq
# xbhn			     xcyh  xepb  xgfv  xhwp  xjnj  xled  xmux  xolr
# xbho			     xcyi  xepc  xgfw  xhwq  xjnk  xlee  xmuy  xols
# xbhp			     xcyj  xepd  xgfx  xhwr  xjnl  xlef  xmuz  xolt
# xbhq			     xcyk  xepe  xgfy  xhws  xjnm  xleg  xmva  xolu
# xbhr			     xcyl  xepf  xgfz  xhwt  xjnn  xleh  xmvb  xolv
# xbhs			     xcym  xepg  xgga  xhwu  xjno  xlei  xmvc  xolw
# xbht			     xcyn  xeph  xggb  xhwv  xjnp  xlej  xmvd  xolx
# xbhu			     xcyo  xepi  xggc  xhww  xjnq  xlek  xmve  xoly
# xbhv			     xcyp  xepj  xggd  xhwx  xjnr  xlel  xmvf  xolz
# xbhw			     xcyq  xepk  xgge  xhwy  xjns  xlem  xmvg  xoma
# xbhx			     xcyr  xepl  xggf  xhwz  xjnt  xlen  xmvh  xomb
# xbhy			     xcys  xepm  xggg  xhxa  xjnu  xleo  xmvi  xomc
# xbhz			     xcyt  xepn  xggh  xhxb  xjnv  xlep  xmvj  xomd
# xbia			     xcyu  xepo  xggi  xhxc  xjnw  xleq  xmvk  xome
# xbib			     xcyv  xepp  xggj  xhxd  xjnx  xler  xmvl  xomf
# xbic			     xcyw  xepq  xggk  xhxe  xjny  xles  xmvm  xomg
# xbid			     xcyx  xepr  xggl  xhxf  xjnz  xlet  xmvn  xomh
# xbie			     xcyy  xeps  xggm  xhxg  xjoa  xleu  xmvo  xomi
# xbif			     xcyz  xept  xggn  xhxh  xjob  xlev  xmvp  xomj
# xbig			     xcza  xepu  xggo  xhxi  xjoc  xlew  xmvq  xomk
# xbih			     xczb  xepv  xggp  xhxj  xjod  xlex  xmvr  xoml
# xbii			     xczc  xepw  xggq  xhxk  xjoe  xley  xmvs  xomm
# xbij			     xczd  xepx  xggr  xhxl  xjof  xlez  xmvt  xomn
# xbik			     xcze  xepy  xggs  xhxm  xjog  xlfa  xmvu  xomo
# xbil			     xczf  xepz  xggt  xhxn  xjoh  xlfb  xmvv  xomp
# xbim			     xczg  xeqa  xggu  xhxo  xjoi  xlfc  xmvw  xomq
# xbin			     xczh  xeqb  xggv  xhxp  xjoj  xlfd  xmvx  xomr
# xbio			     xczi  xeqc  xggw  xhxq  xjok  xlfe  xmvy  xoms
# xbip			     xczj  xeqd  xggx  xhxr  xjol  xlff  xmvz  xomt
# xbiq			     xczk  xeqe  xggy  xhxs  xjom  xlfg  xmwa  xomu
# xbir			     xczl  xeqf  xggz  xhxt  xjon  xlfh  xmwb  xomv
# xbis			     xczm  xeqg  xgha  xhxu  xjoo  xlfi  xmwc  xomw
# xbit			     xczn  xeqh  xghb  xhxv  xjop  xlfj  xmwd  xomx
# xbiu			     xczo  xeqi  xghc  xhxw  xjoq  xlfk  xmwe  xomy
# xbiv			     xczp  xeqj  xghd  xhxx  xjor  xlfl  xmwf  xomz
# xbiw			     xczq  xeqk  xghe  xhxy  xjos  xlfm  xmwg  xona
# xbix			     xczr  xeql  xghf  xhxz  xjot  xlfn  xmwh  xonb
# xbiy			     xczs  xeqm  xghg  xhya  xjou  xlfo  xmwi  xonc
# xbiz			     xczt  xeqn  xghh  xhyb  xjov  xlfp  xmwj  xond
# xbja			     xczu  xeqo  xghi  xhyc  xjow  xlfq  xmwk  xone
# xbjb			     xczv  xeqp  xghj  xhyd  xjox  xlfr  xmwl  xonf
# xbjc			     xczw  xeqq  xghk  xhye  xjoy  xlfs  xmwm  xong
# xbjd			     xczx  xeqr  xghl  xhyf  xjoz  xlft  xmwn  xonh
# xbje			     xczy  xeqs  xghm  xhyg  xjpa  xlfu  xmwo  xoni
# xbjf			     xczz  xeqt  xghn  xhyh  xjpb  xlfv  xmwp  xonj
# xbjg			     xdaa  xequ  xgho  xhyi  xjpc  xlfw  xmwq  xonk
# xbjh			     xdab  xeqv  xghp  xhyj  xjpd  xlfx  xmwr  xonl
# xbji			     xdac  xeqw  xghq  xhyk  xjpe  xlfy  xmws  xonm
# xbjj			     xdad  xeqx  xghr  xhyl  xjpf  xlfz  xmwt  xonn
# xbjk			     xdae  xeqy  xghs  xhym  xjpg  xlga  xmwu  xono
# xbjl			     xdaf  xeqz  xght  xhyn  xjph  xlgb  xmwv  xonp
# xbjm			     xdag  xera  xghu  xhyo  xjpi  xlgc  xmww  xonq
# xbjn			     xdah  xerb  xghv  xhyp  xjpj  xlgd  xmwx  xonr
# xbjo			     xdai  xerc  xghw  xhyq  xjpk  xlge  xmwy  xons
# xbjp			     xdaj  xerd  xghx  xhyr  xjpl  xlgf  xmwz  xont
# xbjq			     xdak  xere  xghy  xhys  xjpm  xlgg  xmxa  xonu
# xbjr			     xdal  xerf  xghz  xhyt  xjpn  xlgh  xmxb  xonv
# xbjs			     xdam  xerg  xgia  xhyu  xjpo  xlgi  xmxc  xonw
# xbjt			     xdan  xerh  xgib  xhyv  xjpp  xlgj  xmxd  xonx
# xbju			     xdao  xeri  xgic  xhyw  xjpq  xlgk  xmxe  xony
# xbjv			     xdap  xerj  xgid  xhyx  xjpr  xlgl  xmxf  xonz
# xbjw			     xdaq  xerk  xgie  xhyy  xjps  xlgm  xmxg  xooa
# xbjx			     xdar  xerl  xgif  xhyz  xjpt  xlgn  xmxh  xoob
# xbjy			     xdas  xerm  xgig  xhza  xjpu  xlgo  xmxi  xooc
# xbjz			     xdat  xern  xgih  xhzb  xjpv  xlgp  xmxj  xood
# xbka			     xdau  xero  xgii  xhzc  xjpw  xlgq  xmxk  xooe
# xbkb			     xdav  xerp  xgij  xhzd  xjpx  xlgr  xmxl  xoof
# xbkc			     xdaw  xerq  xgik  xhze  xjpy  xlgs  xmxm  xoog
# xbkd			     xdax  xerr  xgil  xhzf  xjpz  xlgt  xmxn  xooh
# xbke			     xday  xers  xgim  xhzg  xjqa  xlgu  xmxo  xooi
# xbkf			     xdaz  xert  xgin  xhzh  xjqb  xlgv  xmxp  xooj
# xbkg			     xdba  xeru  xgio  xhzi  xjqc  xlgw  xmxq  xook
# xbkh			     xdbb  xerv  xgip  xhzj  xjqd  xlgx  xmxr  xool
# xbki			     xdbc  xerw  xgiq  xhzk  xjqe  xlgy  xmxs  xoom
# xbkj			     xdbd  xerx  xgir  xhzl  xjqf  xlgz  xmxt  xoon
# xbkk			     xdbe  xery  xgis  xhzm  xjqg  xlha  xmxu  xooo
# xbkl			     xdbf  xerz  xgit  xhzn  xjqh  xlhb  xmxv  xoop
# xbkm			     xdbg  xesa  xgiu  xhzo  xjqi  xlhc  xmxw  xooq
# xbkn			     xdbh  xesb  xgiv  xhzp  xjqj  xlhd  xmxx  xoor
# xbko			     xdbi  xesc  xgiw  xhzq  xjqk  xlhe  xmxy  xoos
# xbkp			     xdbj  xesd  xgix  xhzr  xjql  xlhf  xmxz  xoot
# xbkq			     xdbk  xese  xgiy  xhzs  xjqm  xlhg  xmya  xoou
# xbkr			     xdbl  xesf  xgiz  xhzt  xjqn  xlhh  xmyb  xoov
# xbks			     xdbm  xesg  xgja  xhzu  xjqo  xlhi  xmyc  xoow
# xbkt			     xdbn  xesh  xgjb  xhzv  xjqp  xlhj  xmyd  xoox
# xbku			     xdbo  xesi  xgjc  xhzw  xjqq  xlhk  xmye  xooy
# xbkv			     xdbp  xesj  xgjd  xhzx  xjqr  xlhl  xmyf  xooz
# xbkw			     xdbq  xesk  xgje  xhzy  xjqs  xlhm  xmyg  xopa
# xbkx			     xdbr  xesl  xgjf  xhzz  xjqt  xlhn  xmyh  xopb
# xbky			     xdbs  xesm  xgjg  xiaa  xjqu  xlho  xmyi  xopc
# xbkz			     xdbt  xesn  xgjh  xiab  xjqv  xlhp  xmyj  xopd
# xbla			     xdbu  xeso  xgji  xiac  xjqw  xlhq  xmyk  xope
# xblb			     xdbv  xesp  xgjj  xiad  xjqx  xlhr  xmyl  xopf
# xblc			     xdbw  xesq  xgjk  xiae  xjqy  xlhs  xmym  xopg
# xbld			     xdbx  xesr  xgjl  xiaf  xjqz  xlht  xmyn  xoph
# xble			     xdby  xess  xgjm  xiag  xjra  xlhu  xmyo  xopi
# xblf			     xdbz  xest  xgjn  xiah  xjrb  xlhv  xmyp  xopj
# xblg			     xdca  xesu  xgjo  xiai  xjrc  xlhw  xmyq  xopk
# xblh			     xdcb  xesv  xgjp  xiaj  xjrd  xlhx  xmyr  xopl
# xbli			     xdcc  xesw  xgjq  xiak  xjre  xlhy  xmys  xopm
# xblj			     xdcd  xesx  xgjr  xial  xjrf  xlhz  xmyt  xopn
# xblk			     xdce  xesy  xgjs  xiam  xjrg  xlia  xmyu  xopo
# xbll			     xdcf  xesz  xgjt  xian  xjrh  xlib  xmyv  xopp
# xblm			     xdcg  xeta  xgju  xiao  xjri  xlic  xmyw  xopq
# xbln			     xdch  xetb  xgjv  xiap  xjrj  xlid  xmyx  xopr
# xblo			     xdci  xetc  xgjw  xiaq  xjrk  xlie  xmyy  xops
# xblp			     xdcj  xetd  xgjx  xiar  xjrl  xlif  xmyz  xopt
# xblq			     xdck  xete  xgjy  xias  xjrm  xlig  xmza  xopu
# xblr			     xdcl  xetf  xgjz  xiat  xjrn  xlih  xmzb  xopv
# xbls			     xdcm  xetg  xgka  xiau  xjro  xlii  xmzc  xopw
# xblt			     xdcn  xeth  xgkb  xiav  xjrp  xlij  xmzd  xopx
# xblu			     xdco  xeti  xgkc  xiaw  xjrq  xlik  xmze  xopy
# xblv			     xdcp  xetj  xgkd  xiax  xjrr  xlil  xmzf  xopz
# xblw			     xdcq  xetk  xgke  xiay  xjrs  xlim  xmzg  xoqa
# xblx			     xdcr  xetl  xgkf  xiaz  xjrt  xlin  xmzh  xoqb
# xbly			     xdcs  xetm  xgkg  xiba  xjru  xlio  xmzi  xoqc
# xblz			     xdct  xetn  xgkh  xibb  xjrv  xlip  xmzj  xoqd
# xbma			     xdcu  xeto  xgki  xibc  xjrw  xliq  xmzk  xoqe
# xbmb			     xdcv  xetp  xgkj  xibd  xjrx  xlir  xmzl  xoqf
# xbmc			     xdcw  xetq  xgkk  xibe  xjry  xlis  xmzm  xoqg
# xbmd			     xdcx  xetr  xgkl  xibf  xjrz  xlit  xmzn  xoqh
# xbme			     xdcy  xets  xgkm  xibg  xjsa  xliu  xmzo  xoqi
# xbmf			     xdcz  xett  xgkn  xibh  xjsb  xliv  xmzp  xoqj
# xbmg			     xdda  xetu  xgko  xibi  xjsc  xliw  xmzq  xoqk
# xbmh			     xddb  xetv  xgkp  xibj  xjsd  xlix  xmzr  xoql
# xbmi			     xddc  xetw  xgkq  xibk  xjse  xliy  xmzs  xoqm
# xbmj			     xddd  xetx  xgkr  xibl  xjsf  xliz  xmzt  xoqn
# xbmk			     xdde  xety  xgks  xibm  xjsg  xlja  xmzu  xoqo
# xbml			     xddf  xetz  xgkt  xibn  xjsh  xljb  xmzv  xoqp
# xbmm			     xddg  xeua  xgku  xibo  xjsi  xljc  xmzw  xoqq
# xbmn			     xddh  xeub  xgkv  xibp  xjsj  xljd  xmzx  xoqr
# xbmo			     xddi  xeuc  xgkw  xibq  xjsk  xlje  xmzy  xoqs
# xbmp			     xddj  xeud  xgkx  xibr  xjsl  xljf  xmzz  xoqt
# xbmq			     xddk  xeue  xgky  xibs  xjsm  xljg  xnaa  xoqu
# xbmr			     xddl  xeuf  xgkz  xibt  xjsn  xljh  xnab  xoqv
# xbms			     xddm  xeug  xgla  xibu  xjso  xlji  xnac  xoqw
# xbmt			     xddn  xeuh  xglb  xibv  xjsp  xljj  xnad  xoqx
# xbmu			     xddo  xeui  xglc  xibw  xjsq  xljk  xnae  xoqy
# xbmv			     xddp  xeuj  xgld  xibx  xjsr  xljl  xnaf  xoqz
# xbmw			     xddq  xeuk  xgle  xiby  xjss  xljm  xnag  xora
# xbmx			     xddr  xeul  xglf  xibz  xjst  xljn  xnah  xorb
# xbmy			     xdds  xeum  xglg  xica  xjsu  xljo  xnai  xorc
# xbmz			     xddt  xeun  xglh  xicb  xjsv  xljp  xnaj  xord
# xbna			     xddu  xeuo  xgli  xicc  xjsw  xljq  xnak  xore
# xbnb			     xddv  xeup  xglj  xicd  xjsx  xljr  xnal  xorf
# xbnc			     xddw  xeuq  xglk  xice  xjsy  xljs  xnam  xorg
# xbnd			     xddx  xeur  xgll  xicf  xjsz  xljt  xnan  xorh
# xbne			     xddy  xeus  xglm  xicg  xjta  xlju  xnao  xori
# xbnf			     xddz  xeut  xgln  xich  xjtb  xljv  xnap  xorj
# xbng			     xdea  xeuu  xglo  xici  xjtc  xljw  xnaq  xork
# xbnh			     xdeb  xeuv  xglp  xicj  xjtd  xljx  xnar  xorl
# xbni			     xdec  xeuw  xglq  xick  xjte  xljy  xnas  xorm
# xbnj			     xded  xeux  xglr  xicl  xjtf  xljz  xnat  xorn
# xbnk			     xdee  xeuy  xgls  xicm  xjtg  xlka  xnau  xoro
# xbnl			     xdef  xeuz  xglt  xicn  xjth  xlkb  xnav  xorp
# xbnm			     xdeg  xeva  xglu  xico  xjti  xlkc  xnaw  xorq
# xbnn			     xdeh  xevb  xglv  xicp  xjtj  xlkd  xnax  xorr
# xbno			     xdei  xevc  xglw  xicq  xjtk  xlke  xnay  xors
# xbnp			     xdej  xevd  xglx  xicr  xjtl  xlkf  xnaz  xort
# xbnq			     xdek  xeve  xgly  xics  xjtm  xlkg  xnba  xoru
# xbnr			     xdel  xevf  xglz  xict  xjtn  xlkh  xnbb  xorv
# xbns			     xdem  xevg  xgma  xicu  xjto  xlki  xnbc  xorw
# xbnt			     xden  xevh  xgmb  xicv  xjtp  xlkj  xnbd  xorx
# xbnu			     xdeo  xevi  xgmc  xicw  xjtq  xlkk  xnbe  xory
# xbnv			     xdep  xevj  xgmd  xicx  xjtr  xlkl  xnbf  xorz
# xbnw			     xdeq  xevk  xgme  xicy  xjts  xlkm  xnbg  xosa
# xbnx			     xder  xevl  xgmf  xicz  xjtt  xlkn  xnbh  xosb
# xbny			     xdes  xevm  xgmg  xida  xjtu  xlko  xnbi  xosc
# xbnz			     xdet  xevn  xgmh  xidb  xjtv  xlkp  xnbj  xosd
# xboa			     xdeu  xevo  xgmi  xidc  xjtw  xlkq  xnbk  xose
# xbob			     xdev  xevp  xgmj  xidd  xjtx  xlkr  xnbl  xosf
# xboc			     xdew  xevq  xgmk  xide  xjty  xlks  xnbm  xosg
# xbod			     xdex  xevr  xgml  xidf  xjtz  xlkt  xnbn  xosh
# xboe			     xdey  xevs  xgmm  xidg  xjua  xlku  xnbo  xosi
# xbof			     xdez  xevt  xgmn  xidh  xjub  xlkv  xnbp  xosj
# xbog			     xdfa  xevu  xgmo  xidi  xjuc  xlkw  xnbq  xosk
# xboh			     xdfb  xevv  xgmp  xidj  xjud  xlkx  xnbr  xosl
# xboi			     xdfc  xevw  xgmq  xidk  xjue  xlky  xnbs  xosm
# xboj			     xdfd  xevx  xgmr  xidl  xjuf  xlkz  xnbt  xosn
# xbok			     xdfe  xevy  xgms  xidm  xjug  xlla  xnbu  xoso
# xbol			     xdff  xevz  xgmt  xidn  xjuh  xllb  xnbv  xosp
# xbom			     xdfg  xewa  xgmu  xido  xjui  xllc  xnbw  xosq
# xbon			     xdfh  xewb  xgmv  xidp  xjuj  xlld  xnbx  xosr
# xboo			     xdfi  xewc  xgmw  xidq  xjuk  xlle  xnby  xoss
# xbop			     xdfj  xewd  xgmx  xidr  xjul  xllf  xnbz  xost
# xboq			     xdfk  xewe  xgmy  xids  xjum  xllg  xnca  xosu
# xbor			     xdfl  xewf  xgmz  xidt  xjun  xllh  xncb  xosv
# xbos			     xdfm  xewg  xgna  xidu  xjuo  xlli  xncc  xosw
# xbot			     xdfn  xewh  xgnb  xidv  xjup  xllj  xncd  xosx
# xbou			     xdfo  xewi  xgnc  xidw  xjuq  xllk  xnce  xosy
# xbov			     xdfp  xewj  xgnd  xidx  xjur  xlll  xncf  xosz
# xbow			     xdfq  xewk  xgne  xidy  xjus  xllm  xncg  xota
# xbox			     xdfr  xewl  xgnf  xidz  xjut  xlln  xnch  xotb
# xboy			     xdfs  xewm  xgng  xiea  xjuu  xllo  xnci  xotc
# xboz			     xdft  xewn  xgnh  xieb  xjuv  xllp  xncj  xotd
# xbpa			     xdfu  xewo  xgni  xiec  xjuw  xllq  xnck  xote
# xbpb			     xdfv  xewp  xgnj  xied  xjux  xllr  xncl  xotf
# xbpc			     xdfw  xewq  xgnk  xiee  xjuy  xlls  xncm  xotg
# xbpd			     xdfx  xewr  xgnl  xief  xjuz  xllt  xncn  xoth
# xbpe			     xdfy  xews  xgnm  xieg  xjva  xllu  xnco  xoti
# xbpf			     xdfz  xewt  xgnn  xieh  xjvb  xllv  xncp  xotj
# xbpg			     xdga  xewu  xgno  xiei  xjvc  xllw  xncq  xotk
# xbph			     xdgb  xewv  xgnp  xiej  xjvd  xllx  xncr  xotl
# xbpi			     xdgc  xeww  xgnq  xiek  xjve  xlly  xncs  xotm
# xbpj			     xdgd  xewx  xgnr  xiel  xjvf  xllz  xnct  xotn
# xbpk			     xdge  xewy  xgns  xiem  xjvg  xlma  xncu  xoto
# xbpl			     xdgf  xewz  xgnt  xien  xjvh  xlmb  xncv  xotp
# xbpm			     xdgg  xexa  xgnu  xieo  xjvi  xlmc  xncw  xotq
# xbpn			     xdgh  xexb  xgnv  xiep  xjvj  xlmd  xncx  xotr
# xbpo			     xdgi  xexc  xgnw  xieq  xjvk  xlme  xncy  xots
# xbpp			     xdgj  xexd  xgnx  xier  xjvl  xlmf  xncz  xott
# xbpq			     xdgk  xexe  xgny  xies  xjvm  xlmg  xnda  xotu
# xbpr			     xdgl  xexf  xgnz  xiet  xjvn  xlmh  xndb  xotv
# xbps			     xdgm  xexg  xgoa  xieu  xjvo  xlmi  xndc  xotw
# xbpt			     xdgn  xexh  xgob  xiev  xjvp  xlmj  xndd  xotx
# xbpu			     xdgo  xexi  xgoc  xiew  xjvq  xlmk  xnde  xoty
# xbpv			     xdgp  xexj  xgod  xiex  xjvr  xlml  xndf  xotz
# xbpw			     xdgq  xexk  xgoe  xiey  xjvs  xlmm  xndg  xoua
# xbpx			     xdgr  xexl  xgof  xiez  xjvt  xlmn  xndh  xoub
# xbpy			     xdgs  xexm  xgog  xifa  xjvu  xlmo  xndi  xouc
# xbpz			     xdgt  xexn  xgoh  xifb  xjvv  xlmp  xndj  xoud
# xbqa			     xdgu  xexo  xgoi  xifc  xjvw  xlmq  xndk  xoue
# xbqb			     xdgv  xexp  xgoj  xifd  xjvx  xlmr  xndl  xouf
# xbqc			     xdgw  xexq  xgok  xife  xjvy  xlms  xndm  xoug
# xbqd			     xdgx  xexr  xgol  xiff  xjvz  xlmt  xndn  xouh
# xbqe			     xdgy  xexs  xgom  xifg  xjwa  xlmu  xndo  xoui
# xbqf			     xdgz  xext  xgon  xifh  xjwb  xlmv  xndp  xouj
# xbqg			     xdha  xexu  xgoo  xifi  xjwc  xlmw  xndq  xouk
# xbqh			     xdhb  xexv  xgop  xifj  xjwd  xlmx  xndr  xoul
# xbqi			     xdhc  xexw  xgoq  xifk  xjwe  xlmy  xnds  xoum
# xbqj			     xdhd  xexx  xgor  xifl  xjwf  xlmz  xndt  xoun
# xbqk			     xdhe  xexy  xgos  xifm  xjwg  xlna  xndu  xouo
# xbql			     xdhf  xexz  xgot  xifn  xjwh  xlnb  xndv  xoup
# xbqm			     xdhg  xeya  xgou  xifo  xjwi  xlnc  xndw

# %% [markdown]
# ### From the filesystem to Spark's HDFS filesystem
#
# Spark can't directly read local files on the server.  Instead they need to be copied to the Hadoop distributed filesystem.  Let's start with a connection to HDFS...

# %%
# Next, for Spark we will need to copy the files to HDFS
# So first we need to connect to the HDFS filesystem

######
# From https://diogoalexandrefranco.github.io/interacting-with-hdfs-from-pyspark/
#
# Get fs handler from java gateway
######
URI = sc._gateway.jvm.java.net.URI
Path = sc._gateway.jvm.org.apache.hadoop.fs.Path
FileSystem = sc._gateway.jvm.org.apache.hadoop.fs.FileSystem
fs = FileSystem.get(sc._jsc.hadoopConfiguration())

# Make sure we have an empty directory in HDFS
fs.delete(Path('/in'), True)
fs.mkdirs(Path('/in'))
# Out:
# True

# %% [markdown]
# ### Creating a Streaming (Microbatched) Query
#
# As a first part of this notebook, we will look at doing *incremental computation* over data as it arrives.  To do this we'll use Spark's **microbatch** capability, where it incrementally re-runs a computation based on a "triggering" event (typically a delay).
#
# Here's how this will work
#
# 1. We'll define a "stream query" that gets periodically executed, tracking, for each carrier and flight number, how many flights we've seen so far and the average delay.
# 1. The query will look for csv files as they are added into the `/in` directory, as a series of chunks in a stream.
# 1. We'll parse the CSV format into appropriate columns, arriving at a Spark dataframe.
# 1. This will receive an SQL table name, so we can use it in SparkSQL.

# %%
# We need this to set a schema
from pyspark.sql.types import StructType

# Here's the basic schema of ontime.csv (and its splits)
flightSchema = StructType().add("YEAR", "integer").add("MONTH", "integer")\
  .add("DAY_OF_MONTH", "integer").add("AIRLINE_ID", "integer")\
  .add("CARRIER", "string").add("FL_NUM", "integer").add("ORIGIN", "string")\
  .add("DEST", "string").add("ARR_DELAY", "double").add("CANCELLED", "double")
airlineSchema = StructType().add("IATA_CODE", "string").add("AIRLINE", "string")
airportSchema = StructType().add("IATA_CODE", "string").add("AIRPORT", "string")\
  .add("CITY", "string").add("STATE", "string").add("COUNTRY", "string")\
  .add("LATITUDE", "double").add("LONGITUDE", "double")

# The airlines
airlinesDF = spark.read.option("sep", ",").option("header", "true").\
  schema(airlineSchema).csv('airlines.csv')
airlinesDF.createOrReplaceTempView("airlines")

# The airports
airportsDF = spark.read.option("sep", ",").option("header", "true").\
  schema(airportSchema).csv('airports.csv')
airportsDF.createOrReplaceTempView("airports")

# This will be a stream, and in each microbatch we'll read one file at a time
flightsStreamDF = spark.readStream.option("sep", ",").option("header", "true").\
  option("maxFilesPerTrigger", 1).\
  schema(flightSchema).csv("/in/")
flightsStreamDF.createOrReplaceTempView("flights")


avg_delay = spark.sql("""select CARRIER,FL_NUM, ORIGIN, DEST, org.LATITUDE AS from_lat, org.LONGITUDE AS from_long,
                          dst.LATITUDE AS to_lat, dst.LONGITUDE AS to_long,
                          count(ARR_DELAY) as NbrFlights,
                          avg(ARR_DELAY) as avg_delay
                        from (flights f join airports org on f.origin=org.IATA_CODE) join airports dst on f.dest=dst.IATA_CODE
                        GROUP BY CARRIER, FL_NUM, ORIGIN, DEST, org.LATITUDE, org.LONGITUDE, dst.LATITUDE, dst.LONGITUDE
                        ORDER BY CARRIER, FL_NUM, ORIGIN, DEST""")

# %% [markdown]
# ### Launching the Stream Query
#
# Now we will have to do two things:
# 1. Launch the streaming query (which initially has no data)
# 1. Periodically add new data into the input stream (by copying a file into `/in`).
# 1. Show the updated query results.
#
# This code below will only show the first 4 entries of the stream output, but you should be able to see that evolve over time.  You can press the Stop button to end the query (then execute `query.stop()` in the next cell) or let it run for a long time until it completes.

# %%
# We'll need this to periodically sleep
import time

# Start the query, run every 1 second, recompute the complete output, and in
# each case store it in-memory in a table called flight_info
query = avg_delay.writeStream.outputMode("complete").queryName("flight_info").format("memory").\
    trigger(processingTime='1 seconds').start()

# As the query is running, start copying files from /content into /in
# Then wait 3 sec for Spark to process them, and display the updated output
max = 25
cur = 0
for filename in os.listdir('/content/'):
  if filename.startswith('xaa'):
    cur += 1
    fs.copyFromLocalFile(Path('/content/' + filename),Path('/in'))
    time.sleep(3)
    print(filename)
    display(spark.sql("select * from flight_info").limit(4).toPandas())
    if cur >= max:
      break

query.stop()
# Out:
# xaaa
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaae
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaav
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaaf
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaab
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaaq
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaag
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaad
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaai
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaap
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaam
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaac
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaar
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaal
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaat
# Empty DataFrame
# Columns: [CARRIER, FL_NUM, ORIGIN, DEST, from_lat, from_long, to_lat, to_long, NbrFlights, avg_delay]
# Index: []
# xaax
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaan
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaaj
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaas
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaaw
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaau
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaay
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaao
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaah
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 1      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
# 2      WN     910    SMF  DEN  38.69542 -121.59077  39.85841 -104.66700
# 3      WN     925    SMF  GEG  38.69542 -121.59077  47.61986 -117.53384
#
#    NbrFlights  avg_delay
# 0           1        6.0
# 1           1       23.0
# 2           1        0.0
# 3           1        0.0
# xaaz
#   CARRIER  FL_NUM ORIGIN DEST  from_lat  from_long    to_lat    to_long  \
# 0      WN     668    TPA  BNA  27.97547  -82.53325  36.12448  -86.67818
# 1      WN     704    TPA  BHM  27.97547  -82.53325  33.56294  -86.75355
# 2      WN     792    SMF  BUR  38.69542 -121.59077  34.20062 -118.35850
# 3      WN     844    SJU  TPA  18.43942  -66.00183  27.97547  -82.53325
#
#    NbrFlights  avg_delay
# 0           1        1.0
# 1           1        3.0
# 2           1        6.0
# 3           1       23.0

# %% [markdown]
# ## Time-Windowed Processing
#
# To this point, we've only looked at Spark Streaming from the context of incremental recomputation.  Of course, in many cases you want to do computation over temporal aspects of the data.
#
# For this one we'll use the much bigger longitudinal dataset for 2015 on-time performance.  The schema is considerably bigger than the simpler `ontime.csv`.
#
# For simplicity we will load the whole file into a single dataframe, without streaming.

# %%
# !head 2015-ontime.csv
# Out:
# YEAR,MONTH,DAY,DAY_OF_WEEK,AIRLINE,FLIGHT_NUMBER,TAIL_NUMBER,ORIGIN_AIRPORT,DESTINATION_AIRPORT,SCHEDULED_DEPARTURE,DEPARTURE_TIME,DEPARTURE_DELAY,TAXI_OUT,WHEELS_OFF,SCHEDULED_TIME,ELAPSED_TIME,AIR_TIME,DISTANCE,WHEELS_ON,TAXI_IN,SCHEDULED_ARRIVAL,ARRIVAL_TIME,ARRIVAL_DELAY,DIVERTED,CANCELLED,CANCELLATION_REASON,AIR_SYSTEM_DELAY,SECURITY_DELAY,AIRLINE_DELAY,LATE_AIRCRAFT_DELAY,WEATHER_DELAY
# 2015,1,1,4,AS,98,N407AS,ANC,SEA,0005,2354,-11,21,0015,205,194,169,1448,0404,4,0430,0408,-22,0,0,,,,,,
# 2015,1,1,4,AA,2336,N3KUAA,LAX,PBI,0010,0002,-8,12,0014,280,279,263,2330,0737,4,0750,0741,-9,0,0,,,,,,
# 2015,1,1,4,US,840,N171US,SFO,CLT,0020,0018,-2,16,0034,286,293,266,2296,0800,11,0806,0811,5,0,0,,,,,,
# 2015,1,1,4,AA,258,N3HYAA,LAX,MIA,0020,0015,-5,15,0030,285,281,258,2342,0748,8,0805,0756,-9,0,0,,,,,,
# 2015,1,1,4,AS,135,N527AS,SEA,ANC,0025,0024,-1,11,0035,235,215,199,1448,0254,5,0320,0259,-21,0,0,,,,,,
# 2015,1,1,4,DL,806,N3730B,SFO,MSP,0025,0020,-5,18,0038,217,230,206,1589,0604,6,0602,0610,8,0,0,,,,,,
# 2015,1,1,4,NK,612,N635NK,LAS,MSP,0025,0019,-6,11,0030,181,170,154,1299,0504,5,0526,0509,-17,0,0,,,,,,
# 2015,1,1,4,US,2013,N584UW,LAX,CLT,0030,0044,14,13,0057,273,249,228,2125,0745,8,0803,0753,-10,0,0,,,,,,
# 2015,1,1,4,AA,1112,N3LAAA,SFO,DFW,0030,0019,-11,17,0036,195,193,173,1464,0529,3,0545,0532,-13,0,0,,,,,,

# %%
# We need this to set a schema
from pyspark.sql.types import StructType
from pyspark.sql.functions import window

fs.copyFromLocalFile(Path('/content/2015-ontime.csv'),Path('/2015-ontime.csv'))

# Here's the basic schema of ontime.csv (and its splits)
ontimeSchema = StructType().add("YEAR", "integer").add("MONTH", "integer")\
  .add("DAY", "integer").add("DAY_OF_WEEK", "integer").add("AIRLINE_ID", "string")\
  .add("FL_NUM", "integer").add("TAIL_NUM", "string").add("ORIGIN", "string")\
  .add("DEST", "string").add("SCH_DEPARTURE", "integer").add("DEPARTURE", "integer")\
  .add("DEP_DELAY","integer").add("TAXI_OUT","integer").add("WHEELS_OFF","integer")\
  .add("SCH_TIME","integer").add("ELAPSED_TIME","integer").add("AIR_TIME","integer")\
  .add("DISTANCE","integer").add("WHEELS_ON","integer").add("TAXI_IN","integer")\
  .add("SCH_ARRIVAL","integer").add("ARRIVAL_TIME","integer")\
  .add("ARR_DELAY", "integer").add("DIVERTED", "integer").add("CANCELLED", "integer")\
  .add("CANCELLATION_REASON","string").add("AIR_SYSTEM_DELAY", "integer")\
  .add("SECURITY_DELAY", "integer").add("AIRLINE_DELAY", "integer")\
  .add("LATE_AIRCRAFT_DELAY", "integer").add("WEATHER_DELAY", "integer")

# This will be a stream, and in each microbatch we'll read one file at a time
ontimeDF = spark.read.option("sep", ",").option("header", "true").\
  schema(ontimeSchema).csv("/2015-ontime.csv")
ontimeDF.createOrReplaceTempView("ontime")

display(ontimeDF.take(2))
# Out:
# [Row(YEAR=2015, MONTH=1, DAY=1, DAY_OF_WEEK=4, AIRLINE_ID='AS', FL_NUM=98, TAIL_NUM='N407AS', ORIGIN='ANC', DEST='SEA', SCH_DEPARTURE=5, DEPARTURE=2354, DEP_DELAY=-11, TAXI_OUT=21, WHEELS_OFF=15, SCH_TIME=205, ELAPSED_TIME=194, AIR_TIME=169, DISTANCE=1448, WHEELS_ON=404, TAXI_IN=4, SCH_ARRIVAL=430, ARRIVAL_TIME=408, ARR_DELAY=-22, DIVERTED=0, CANCELLED=0, CANCELLATION_REASON=None, AIR_SYSTEM_DELAY=None, SECURITY_DELAY=None, AIRLINE_DELAY=None, LATE_AIRCRAFT_DELAY=None, WEATHER_DELAY=None),
#  Row(YEAR=2015, MONTH=1, DAY=1, DAY_OF_WEEK=4, AIRLINE_ID='AA', FL_NUM=2336, TAIL_NUM='N3KUAA', ORIGIN='LAX', DEST='PBI', SCH_DEPARTURE=10, DEPARTURE=2, DEP_DELAY=-8, TAXI_OUT=12, WHEELS_OFF=14, SCH_TIME=280, ELAPSED_TIME=279, AIR_TIME=263, DISTANCE=2330, WHEELS_ON=737, TAXI_IN=4, SCH_ARRIVAL=750, ARRIVAL_TIME=741, ARR_DELAY=-9, DIVERTED=0, CANCELLED=0, CANCELLATION_REASON=None, AIR_SYSTEM_DELAY=None, SECURITY_DELAY=None, AIRLINE_DELAY=None, LATE_AIRCRAFT_DELAY=None, WEATHER_DELAY=None)]

# %%
simplerDF = spark.sql("""select cast(concat(cast(YEAR as string), '-',
                      cast (MONTH as string), '-', CAST (DAY as string), ' ',
                      cast(cast (SCH_DEPARTURE / 100 as integer) as string), ':',
                           cast (SCH_DEPARTURE % 100 as string) ) as timestamp) as YMD,
                      AIRLINE_ID, ORIGIN, DEST, DISTANCE, ARR_DELAY,
                      (SCH_ARRIVAL - SCH_DEPARTURE + 2400) % 2400 as SCH_DURATION
                      from ontime""")
simplerDF.createOrReplaceTempView("simpler")

w = simplerDF.groupBy(
    window(simplerDF.YMD, "1 day", "1 day"),
    simplerDF.ORIGIN,
    simplerDF.DEST
).avg()

w
# Out:
# DataFrame[window: struct<start:timestamp,end:timestamp>, ORIGIN: string, DEST: string, avg(DISTANCE): double, avg(ARR_DELAY): double, avg(SCH_DURATION): double]

# %%
from pyspark.sql.functions import window, month, dayofmonth, hour


windowedDelays = w.select(month(w.window.start).alias("month"),\
                          dayofmonth(w.window.start).alias("day"),\
                          hour(w.window.start).alias("hour"),\
                          w.ORIGIN, w.DEST,\
               w['avg(DISTANCE)'].alias("distance"),
               w['avg(SCH_DURATION)'].alias("duration"),
               w['avg(ARR_DELAY)'].alias("delay"))

delayDF = windowedDelays.filter(windowedDelays.month == 2)\
  .orderBy(windowedDelays.delay.desc()).toPandas()

# %%
delayDF
# Out:
#         month  day  hour ORIGIN DEST  distance     duration   delay
# 0           2    9     0    JFK  HNL    4983.0   615.000000  1467.0
# 1           2   22     0    EGE  ORD    1007.0   338.000000  1460.0
# 2           2    8     0    HNL  JFK    4983.0  1425.000000  1391.0
# 3           2   27     0    DFW  HNL    3784.0   461.000000  1295.0
# 4           2   28     0    ORD  EGE    1007.0   190.000000  1235.0
# ...       ...  ...   ...    ...  ...       ...          ...     ...
# 104440      2   21     0    EWR  GSP     594.0   204.000000     NaN
# 104441      2   21     0    DCA  CAK     274.0   155.000000     NaN
# 104442      2   23     0    MLU  DFW     293.0   146.000000     NaN
# 104443      2   23     0    GRK  DFW     134.0    90.555556     NaN
# 104444      2   28     0    CHS  DFW     987.0   256.500000     NaN
#
# [104445 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

# Take the dataframe and one-hot encode the airport origins and destinations
main_df = pd.concat([delayDF, pd.get_dummies(delayDF[['ORIGIN']],prefix='ORIGIN', drop_first=True),
          pd.get_dummies(delayDF[['DEST']],prefix='DEST', drop_first=True)], axis=1)

main_df.drop(['ORIGIN','DEST'], axis=1, inplace=True)

# Drop outliers (more than an hour) and mark things that arrive early as having 0 delay
main_df['delay'] = main_df['delay'].apply(lambda x: x if x >= 0 and x < 60 else 0 if x < 0 else np.nan)

# Some entries, such as delay, show up with NaN
main_df.dropna(how='any', axis=0, inplace=True)

main_df
# Out:
#         month  day  hour  distance    duration      delay  ORIGIN_ABI  \
# 5960        2   26     0     108.0   97.500000  59.888889       False
# 5961        2    2     0     762.0  220.461538  59.857143       False
# 5962        2    8     0     475.0  266.000000  59.833333       False
# 5963        2   20     0    1325.0  289.500000  59.833333       False
# 5964        2   25     0     997.0  303.833333  59.833333       False
# ...       ...  ...   ...       ...         ...        ...         ...
# 102001      2    8     0    2520.0  885.000000   0.000000       False
# 102002      2    7     0    1504.0  370.000000   0.000000       False
# 102003      2   22     0    2607.0  428.000000   0.000000       False
# 102004      2   19     0    2520.0  885.000000   0.000000       False
# 102005      2    6     0    2994.0  961.000000   0.000000       False
#
#         ORIGIN_ABQ  ORIGIN_ABR  ORIGIN_ABY  ...  DEST_TYR  DEST_TYS  DEST_UST  \
# 5960         False       False       False  ...     False     False     False
# 5961         False       False       False  ...     False     False     False
# 5962         False       False       False  ...     False      True     False
# 5963         False       False       False  ...     False     False     False
# 5964         False       False       False  ...     False     False     False
# ...            ...         ...         ...  ...       ...       ...       ...
# 102001       False       False       False  ...     False     False     False
# 102002       False       False       False  ...     False     False     False
# 102003       False       False       False  ...     False     False     False
# 102004       False       False       False  ...     False     False     False
# 102005       False       False       False  ...     False     False     False
#
#         DEST_VEL  DEST_VLD  DEST_VPS  DEST_WRG  DEST_XNA  DEST_YAK  DEST_YUM
# 5960       False     False     False     False     False     False     False
# 5961       False     False     False     False     False     False     False
# 5962       False     False     False     False     False     False     False
# 5963       False     False     False     False     False     False     False
# 5964       False     False     False     False     False     False     False
# ...          ...       ...       ...       ...       ...       ...       ...
# 102001     False     False     False     False     False     False     False
# 102002     False     False     False     False     False     False     False
# 102003     False     False     False     False     False     False     False
# 102004     False     False     False     False     False     False     False
# 102005     False     False     False     False     False     False     False
#
# [96046 rows x 634 columns]

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

y = main_df['delay']
X = main_df.drop(['delay'], axis=1)

delay_X_train, delay_X_test, delay_y_train, delay_y_test = train_test_split(\
  X, y, test_size=0.20, random_state=42)
regr = linear_model.LinearRegression()

regr.fit(delay_X_train, delay_y_train)
# Out:
# LinearRegression()

# %%
X.columns
# Out:
# Index(['month', 'day', 'hour', 'distance', 'duration', 'ORIGIN_ABI',
#        'ORIGIN_ABQ', 'ORIGIN_ABR', 'ORIGIN_ABY', 'ORIGIN_ACT',
#        ...
#        'DEST_TYR', 'DEST_TYS', 'DEST_UST', 'DEST_VEL', 'DEST_VLD', 'DEST_VPS',
#        'DEST_WRG', 'DEST_XNA', 'DEST_YAK', 'DEST_YUM'],
#       dtype='object', length=633)

# %%
y_pred = regr.predict(delay_X_test)

# %% [markdown]
# What do the errors look like?

# %%
y_pred - delay_y_test
# Out:
# 52753     3.417698
# 31759    -3.500301
# 49075     5.828158
# 50030     2.927529
# 97828     4.715536
#            ...
# 74926     5.469873
# 21647   -11.156651
# 27981    -1.449696
# 66845     3.146580
# 60324     4.659288
# Name: delay, Length: 19210, dtype: float64

# %% [markdown]
# Let's analyze more systematically, using mean squared error and variance...

# %%
# The coefficients
print("# coefficients: \n", len(regr.coef_))
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(delay_y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(delay_y_test, y_pred))
# Out:
# # coefficients:
#  633
# Coefficients:
#  [-1.00760127e-13  1.38388851e-01  9.20787752e-13 -4.15497318e-04
#  -1.76129686e-03 -7.56785429e+00 -5.10192640e+00 -6.98906566e+00
#  -5.60652894e+00 -6.94716771e+00 -5.39554104e+00 -3.82209604e+00
#   2.20633020e+00 -9.92247795e+00 -3.13373076e+00 -1.34742466e+00
#  -5.76914933e+00 -7.01590586e+00 -5.33075946e+00 -7.05234857e+00
#  -3.04114202e+00 -3.27898236e+00 -4.35918828e+00 -5.58127036e+00
#  -4.77540477e+00 -8.35488323e+00 -7.50383773e+00 -5.19446415e+00
#  -3.35048582e+00 -3.70657082e+00 -8.29625668e+00  3.10726583e+00
#  -3.14503607e+00 -5.78197463e+00 -7.78811496e+00 -3.19714586e+00
#  -1.04445061e+01 -7.68179712e+00 -3.01575677e+00 -4.69474007e+00
#  -7.28075213e+00  2.67339262e+00 -8.36236565e-01 -6.84787742e+00
#  -6.79253404e+00 -7.76998073e+00 -6.00406621e+00 -4.02522344e+00
#  -9.24055373e+00 -2.35391570e+00 -1.15162081e+00 -3.86191738e+00
#  -4.96735007e+00 -2.79549435e+00 -6.31699990e+00 -1.31908958e+00
#  -7.00200299e+00 -7.85182743e+00 -6.74958438e+00 -6.84224975e+00
#  -3.84836199e+00 -7.22921102e+00 -5.59282621e+00 -2.54820607e+00
#  -7.16389672e-01 -2.90317153e+00 -2.43519910e+00 -4.64005327e+00
#  -2.57619800e+00 -3.67088482e+00 -5.68647742e+00 -8.74402924e+00
#  -8.67077075e+00 -1.44962072e+00 -5.91373841e+00  5.44785004e-01
#  -5.85782244e+00 -3.48077279e+00 -4.64712812e+00 -2.48300903e+00
#  -2.16590180e+00 -2.46258301e+00 -1.13363128e+00 -3.96453224e+00
#  -5.10058025e+00 -1.01599890e+01 -4.31618283e+00  6.16670974e-01
#  -1.96456835e+00 -3.74591196e+00 -3.14281998e+00 -4.66954504e+00
#  -4.26824415e+00 -4.37363039e+00 -2.54193615e+00 -5.93457716e+00
#  -9.92115297e+00 -4.13082903e+00 -5.75893346e+00 -7.38789889e+00
#  -4.05714723e+00 -5.43929577e+00 -5.30340312e+00 -7.22154805e+00
#  -8.12098419e+00 -1.60455043e+00 -6.51325352e+00 -2.44009987e+00
#  -6.46486276e+00 -7.97912472e+00 -3.74389482e+00 -5.74699755e+00
#  -4.50247127e+00 -7.07012473e+00 -5.36555327e+00 -3.68510820e+00
#  -7.89815713e+00 -2.71288497e+00 -2.02910021e+00 -1.02972821e+00
#  -8.70366093e+00 -4.49782628e+00 -7.92349905e+00 -3.39110672e+00
#  -1.25911103e+00 -7.64184260e+00 -1.30554086e+00 -7.37737165e+00
#  -5.99747028e+00 -4.48101489e+00 -5.21943120e+00 -6.19182369e+00
#  -4.77198394e+00 -4.07173103e+00 -6.81785938e+00 -3.36392906e+00
#  -9.88826484e+00 -8.64326376e+00 -5.27892274e+00 -3.56799303e+00
#  -9.45733336e+00 -4.03280250e+00 -6.58913832e+00 -4.67940152e+00
#  -1.45661154e+00 -8.97165866e+00 -5.45907559e+00 -4.16999043e+00
#  -4.15230550e+00  9.06477822e-01 -4.38626140e+00 -4.65633833e+00
#  -5.73048607e+00 -3.88468202e+00 -6.92359349e+00 -6.16791645e+00
#  -4.16181937e+00 -6.20516594e+00 -3.78058863e+00 -3.18279069e+00
#  -1.39753561e+00 -9.74607186e+00 -4.45263704e+00 -4.18407481e+00
#  -3.05855324e+00 -8.30995380e-02 -3.84447230e+00 -4.96527051e+00
#  -3.73875482e+00 -6.00545730e+00 -8.46841570e+00 -3.53154207e+00
#  -1.10988890e+01 -3.29778879e+00 -4.19293424e+00 -3.70765485e+00
#  -5.47310624e+00 -1.15935941e+00 -6.97932878e+00 -2.65216963e+00
#  -4.87294406e+00  3.00889576e+00 -5.27550356e+00 -8.55174913e+00
#  -5.01596759e+00 -7.11657774e+00 -8.31701882e+00 -8.29197861e+00
#  -6.54829953e+00 -4.65381070e+00 -8.04086954e+00 -5.19940168e+00
#  -3.35674427e+00 -5.18985388e+00 -3.96247133e+00 -9.24361693e+00
#  -5.06799837e+00 -7.37320411e+00 -6.36032760e+00 -3.55559609e+00
#  -8.36574539e+00 -4.16824623e+00 -2.98521675e+00 -4.86490491e+00
#  -9.94974728e-01 -8.08453457e+00 -3.26879181e+00 -2.81706739e+00
#  -5.16808654e+00 -3.65756857e+00 -5.91794524e+00 -1.21774690e+01
#  -5.13933434e+00 -3.76211223e+00 -8.41732779e+00 -4.97359718e+00
#  -4.81129365e+00 -5.09272518e+00 -4.63869187e+00 -2.41975913e+00
#  -5.70247370e+00 -5.32361838e+00 -3.46358853e+00 -4.09234034e+00
#  -5.73694484e-01 -5.14626091e+00  3.22467574e+00 -4.34355366e+00
#  -4.16142769e+00 -3.41152186e+00 -1.60451894e+00 -1.18767965e+01
#  -2.38393408e+00 -2.15503840e+00 -6.43877237e+00 -2.66363787e-01
#  -2.32042764e+00 -4.45980580e+00 -4.58648800e+00 -5.65111865e+00
#  -7.79730891e+00 -5.64259245e+00 -6.45964303e+00 -5.43368585e+00
#   1.04118863e+01 -1.05125346e+01 -8.57986817e+00 -5.15735894e+00
#  -4.02700515e+00 -6.20252018e+00 -2.68592383e+00 -7.23788493e+00
#  -7.77501856e+00 -9.44703918e+00 -6.75683732e+00 -4.45918797e+00
#  -6.49076463e+00 -3.95859708e+00 -9.14438813e+00 -6.63179703e+00
#  -6.17832873e+00 -4.84267112e+00 -2.23437754e+00 -5.49899016e+00
#  -2.21714361e+00 -5.72474020e+00 -4.98110131e+00 -5.06071334e+00
#  -4.25684849e+00 -6.52924561e+00  4.49396261e-01 -6.53876239e+00
#  -7.95180778e+00 -8.63274304e+00 -5.43948046e+00 -5.85967534e+00
#  -2.05611005e+00 -4.15264586e+00 -6.81596320e+00 -3.87440659e+00
#  -4.45979432e+00 -6.35274306e+00 -5.83192493e+00 -2.05633407e+00
#  -7.79289443e+00 -4.90966201e+00 -1.25178588e+00 -5.07474119e+00
#  -2.29880008e+00 -8.45018270e+00 -7.14082168e+00 -4.86726226e+00
#  -3.72449634e+00 -4.29212685e+00 -4.63077972e+00 -5.78836389e+00
#  -2.90524970e+00 -3.33053499e+00 -4.18859579e+00 -1.07793842e+00
#  -7.16016758e+00 -4.16440108e+00 -6.43615821e+00  4.58879561e-01
#  -4.54895953e+00 -6.45443339e+00 -4.67182674e+00 -8.95179709e+00
#  -8.84644269e+00 -3.17973933e+00 -1.41318852e+00 -1.56450700e+01
#  -9.34767420e+00 -2.11452772e+00 -3.35027762e+00 -8.13493225e+00
#  -1.39039110e+00 -9.80739410e+00 -6.75735374e+00 -4.53537607e+00
#  -1.72366004e+00 -3.66526754e+00 -4.18231932e+00 -5.53158393e+00
#  -3.07951396e+00  1.52903532e+00 -2.69333435e+00 -2.52478030e+00
#  -2.54744852e+00  9.98386833e-01 -2.69525528e+00  4.29484781e+00
#  -2.75807685e+00 -2.68134669e+00  3.19969762e+00  1.24179147e+00
#  -2.85959292e+00  1.32902248e+00 -1.25236274e+00 -2.42392233e+00
#   1.98267213e+00  2.09701122e+00 -4.96333009e-01  7.62017835e-01
#  -3.45707549e+00  1.96052965e+00 -6.23473024e-01 -2.45774059e+00
#  -2.15310497e+00  1.18956731e+00 -7.39791901e+00 -1.96118269e+00
#   3.44557460e+00 -3.61755373e+00  1.02147059e+00  4.65091278e+00
#   4.23173473e+00 -2.34960230e+00  2.65618566e+00 -6.14438434e+00
#  -3.87360949e+00  3.21506517e+00 -3.98696691e+00 -1.10044872e+00
#   5.28717623e-01 -2.10727640e+00 -1.56757012e+00 -2.55730515e+00
#  -2.81545658e+00  9.51948331e-01 -6.09156101e+00 -1.09849475e+00
#  -5.00715994e-01  7.46864971e-01 -1.82908706e+00  2.61698866e+00
#  -2.23274004e+00  2.94281071e+00 -3.93790373e+00 -7.49598407e-01
#  -1.21689136e+00 -1.31841837e+00 -2.51743032e+00 -1.81138390e+00
#   1.89172048e+00 -4.16388501e+00 -2.71241462e+00 -1.81623618e+00
#   5.28900971e-01  3.07550752e+00 -4.63244826e+00 -1.78402338e-01
#  -4.29301518e+00  3.04186268e-02 -2.28318238e+00  3.57781883e+00
#   5.10129793e-01 -2.72379845e+00 -2.63226758e+00  3.75761732e+00
#  -2.06009748e+00  4.99436479e-01 -5.66227176e-01  5.80322080e-01
#  -2.63190420e+00 -4.36400467e+00 -1.92200601e+00 -1.47655826e+00
#  -1.46147526e+00  9.96022105e-02 -1.02509307e+01 -3.17871546e+00
#  -3.20371501e+00  6.16862469e-01  7.52627848e+00 -1.53288781e+00
#  -7.85023470e+00 -5.64935048e+00 -2.54414347e+00  1.99255332e+00
#   3.95569125e+00 -2.63976863e-01 -4.92443504e+00 -1.53405151e+00
#  -1.83705931e+00 -1.45443191e+00 -6.24927942e+00 -1.33892863e+00
#  -4.88136516e+00 -9.18662632e-01 -4.36316473e+00  1.70587009e+00
#   1.15683625e+00  1.22587560e+00 -3.94871739e+00  5.72267985e-01
#  -2.88026353e+00  2.11612738e+00 -4.46894500e+00 -3.11192775e+00
#  -7.08860133e-01 -2.06927906e+00  4.79590036e-01  2.88373637e+00
#  -1.40684013e+00 -9.82124317e-01  1.48168840e+00 -2.84874280e+00
#  -2.06054394e+00  1.64027125e+00 -7.03978147e+00  6.45186321e+00
#  -3.78216007e+00 -2.92583359e+00 -3.68232651e+00  3.35522850e+00
#  -3.32769320e+00 -2.86574520e+00  3.04578450e+00 -4.45665975e+00
#  -7.62173952e-01 -5.84392343e+00 -1.98584605e+00 -2.56231020e+00
#  -2.30920659e+00 -2.32532285e+00 -1.04824807e+00 -1.69770252e+00
#  -6.70310862e+00 -4.86823150e+00 -1.74460571e+00 -3.66598951e+00
#   4.39897233e-02 -1.89374860e+00  1.12357021e+01 -5.34291865e+00
#  -3.03755995e+00 -2.11775668e+00 -2.18384522e+00  1.94798661e+00
#  -1.33705131e+00 -1.59198729e+00 -2.19779628e+00 -1.03942816e+00
#  -4.24169349e+00  2.89008767e-01 -6.81994685e+00 -2.15666786e+00
#   1.46259921e+00 -8.64417318e-01 -2.95399146e+00 -3.49600657e-01
#  -5.68643852e+00 -1.28744318e+00 -4.25795936e+00  4.80500891e+00
#  -3.48735818e+00 -8.79050837e-01 -1.71134415e+00 -1.56067470e+00
#  -4.48945840e+00  3.61041288e+00 -3.45866323e+00 -1.77281839e+00
#  -3.34813250e+00 -1.89806368e+00 -1.04519441e+00 -2.76125553e+00
#  -2.61198417e+00 -4.93837685e+00 -2.36767013e+00 -3.98898096e+00
#  -4.02135876e+00  5.06926445e+00 -1.17543937e+00 -3.98167073e+00
#  -1.62996654e+00 -2.36222870e+00 -4.22545015e+00 -3.33647299e-01
#  -1.46208445e+00 -3.32211502e+00 -5.45467144e+00 -4.37637526e+00
#   4.44489889e+00  1.87158569e+00 -6.78753087e-01 -1.29476716e+00
#  -7.28237670e-01 -2.46388234e+00 -2.72548188e+00 -2.45499364e+00
#  -3.15782192e+00  1.21994914e+00 -2.65653346e+00 -6.65977928e-01
#  -1.10444044e+00 -1.96923010e+00  8.90782905e-01 -1.08687519e+00
#   3.70335450e+00 -2.47278443e+00 -9.53414159e-01  1.21912887e+00
#   2.09634334e+00 -1.05689383e+01  1.48159610e+00 -1.11500896e+00
#  -2.63613678e+00 -1.16648303e+00 -8.52869023e-01 -2.84197619e+00
#  -7.36228445e-01  2.24772240e+00 -4.61878742e+00 -5.50660557e-01
#   1.41489711e+00 -2.42337819e+00 -3.23833256e+00 -3.35760260e+00
#  -2.61405858e+00 -1.23171933e+00 -3.31926482e+00 -7.43111915e+00
#   1.19067622e+00  1.14116400e+00 -2.39795987e+00  3.46312353e-01
#  -3.08479044e+00 -2.49060889e+00 -2.93574785e+00 -8.14227743e-01
#  -6.64703375e+00 -3.40308961e+00  1.44992333e-01 -3.27262925e+00
#   3.03647087e+00  1.11188601e+00 -1.88473736e+00 -2.01619762e+00
#  -2.48161576e+00 -1.90050015e+00 -2.61849090e+00 -1.73258504e+00
#   2.11676299e+00 -4.49407542e+00 -3.01630867e+00  8.28212052e-01
#  -2.41885968e+00 -2.75413582e+00  8.42288204e-01  8.35205263e-01
#  -4.28958830e+00 -1.81365273e+00 -4.75403743e+00 -3.50665656e+00
#  -1.23659197e+00  2.72743578e-01 -4.05959177e+00 -2.04450008e+00
#  -2.64682794e+00 -4.19367159e+00  1.75945960e+00 -2.42501545e+00
#  -3.99198896e+00 -4.70849215e+00 -2.49805350e+00 -3.12394430e+00
#  -4.54497130e+00  2.77949726e-01  1.05141508e+01 -3.28415765e+00
#  -9.65685467e-02  1.97870204e+00  1.01080143e+00 -2.28650651e+00
#  -2.74383153e+00  4.83362631e+00 -2.82805926e+00 -2.88042926e+00
#  -3.98998073e-01 -1.19795145e+00 -8.00768204e+00 -3.36183577e-01
#   4.48635820e-01 -1.52187109e+00 -5.68588427e+00 -1.90249807e+00
#  -4.57591586e+00 -4.18074783e+00 -1.19064998e+00 -5.34070874e+00
#  -8.54824800e+00]
# Mean squared error: 156.23
# Variance score: 0.06

# %% [markdown]
# ## Exercise
#
# See if you can combine the incremental stream processing portion of the notebook with the time window-based computation!

# %% [markdown]
# ### Autograder setup

# %%
#PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO
#TO ASSIGN POINTS TO YOU IN OUR BACKEND
STUDENT_ID = 64660501 # YOUR PENN-ID GOES HERE AS AN INTEGER##PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO

# %%
# %%writefile notebook-config.yaml
#
# grader_api_url: 'https://23whrwph9h.execute-api.us-east-1.amazonaws.com/default/Grader23'
# grader_api_key: 'flfkE736fA6Z8GxMDJe2q8Kfk8UDqjsG3GVqOFOa'
# Out:
# Writing notebook-config.yaml

# %%
# %set_env HW_ID=cis5450_25f_HW9
# Out:
# env: HW_ID=cis5450_25f_HW9

# %%
# !pip3 install penngrader-client
# Out:
# Collecting penngrader-client
#   Downloading penngrader_client-0.5.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from penngrader-client) (0.3.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from penngrader-client) (6.0.3)
# Downloading penngrader_client-0.5.2-py3-none-any.whl (10 kB)
# Installing collected packages: penngrader-client
# Successfully installed penngrader-client-0.5.2

# %%
import os
from penngrader.grader import *

grader = PennGrader('notebook-config.yaml', os.environ['HW_ID'], STUDENT_ID, STUDENT_ID)
# Out:
# PennGrader initialized with Student ID: 64660501
#
# Make sure this correct or we will not be able to store your grade

# %%
delay_X_train
# Out:
#        month  day  hour  distance    duration  ORIGIN_ABI  ORIGIN_ABQ  \
# 73587      2   14     0    1634.0  530.000000       False       False
# 79526      2   27     0     632.0  241.200000       False       False
# 78556      2   26     0     733.0  294.000000       False       False
# 21978      2   10     0     125.0   87.333333       False       False
# 66452      2   11     0     569.0  261.750000       False        True
# ...      ...  ...   ...       ...         ...         ...         ...
# 12225      2   16     0    1506.0  537.000000       False       False
# 60846      2   24     0     216.0  105.000000       False       False
# 82780      2   20     0     574.0  120.500000       False       False
# 6820       2   19     0     833.0  315.500000       False       False
# 21755      2   22     0     813.0  153.000000       False       False
#
#        ORIGIN_ABR  ORIGIN_ABY  ORIGIN_ACT  ...  DEST_TYR  DEST_TYS  DEST_UST  \
# 73587       False       False       False  ...     False     False     False
# 79526       False       False       False  ...     False     False     False
# 78556       False       False       False  ...     False     False     False
# 21978       False       False       False  ...     False     False     False
# 66452       False       False       False  ...     False     False     False
# ...           ...         ...         ...  ...       ...       ...       ...
# 12225       False       False       False  ...     False     False     False
# 60846       False       False       False  ...     False     False     False
# 82780       False       False       False  ...     False     False     False
# 6820        False       False       False  ...     False     False     False
# 21755       False       False       False  ...     False     False     False
#
#        DEST_VEL  DEST_VLD  DEST_VPS  DEST_WRG  DEST_XNA  DEST_YAK  DEST_YUM
# 73587     False     False     False     False     False     False     False
# 79526     False     False     False     False     False     False     False
# 78556     False     False     False     False     False     False     False
# 21978     False     False     False     False     False     False     False
# 66452     False     False     False     False     False     False     False
# ...         ...       ...       ...       ...       ...       ...       ...
# 12225     False     False     False     False     False     False     False
# 60846     False     False     False     False     False     False     False
# 82780     False     False     False     False     False     False     False
# 6820      False     False     False     False     False     False     False
# 21755     False     False     False     False     False     False     False
#
# [76836 rows x 633 columns]

# %%
delay_X_test
# Out:
#        month  day  hour  distance    duration  ORIGIN_ABI  ORIGIN_ABQ  \
# 52753      2   16     0    1927.0  601.333333       False       False
# 31759      2    8     0    1008.0  374.750000       False       False
# 49075      2   12     0     533.0  252.500000       False       False
# 50030      2   18     0    2640.0  765.250000       False       False
# 97828      2   12     0     846.0  222.000000       False       False
# ...      ...  ...   ...       ...         ...         ...         ...
# 74926      2   13     0    1139.0  118.600000       False       False
# 21647      2   19     0    1067.0  102.500000       False       False
# 27981      2   10     0    1250.0  269.142857       False       False
# 66845      2    5     0     493.0  261.500000       False       False
# 60324      2   18     0     488.0  127.500000       False       False
#
#        ORIGIN_ABR  ORIGIN_ABY  ORIGIN_ACT  ...  DEST_TYR  DEST_TYS  DEST_UST  \
# 52753       False       False       False  ...     False     False     False
# 31759       False       False       False  ...     False     False     False
# 49075       False       False       False  ...     False     False     False
# 50030       False       False       False  ...     False     False     False
# 97828       False       False       False  ...     False     False     False
# ...           ...         ...         ...  ...       ...       ...       ...
# 74926       False       False       False  ...     False     False     False
# 21647       False       False       False  ...     False     False     False
# 27981       False       False       False  ...     False     False     False
# 66845       False       False       False  ...     False     False     False
# 60324       False       False       False  ...     False     False     False
#
#        DEST_VEL  DEST_VLD  DEST_VPS  DEST_WRG  DEST_XNA  DEST_YAK  DEST_YUM
# 52753     False     False     False     False     False     False     False
# 31759     False     False     False     False     False     False     False
# 49075     False     False     False     False     False     False     False
# 50030     False     False     False     False     False     False     False
# 97828     False     False     False     False     False     False     False
# ...         ...       ...       ...       ...       ...       ...       ...
# 74926     False     False     False     False     False     False     False
# 21647     False     False     False     False     False     False     False
# 27981     False     False     False     False     False     False     False
# 66845     False     False     False     False     False     False     False
# 60324     False     False     False     False     False     False     False
#
# [19210 rows x 633 columns]

# %% [markdown]
# # Let's train over the training set
#
# Use the VectorAssembler to convert inputCols into a vector, stored in a column called `features`.  Apply to the trainign data.
#
# Then use MLLib's LinearRegression to train a model, much as SciKit would do it.

# %%
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import VectorAssembler

# TODO: Use the VectorAssembler to convert inputCols into a vector in a column called `features`
# and be careful to not include the otuput you're predicting
vecAssembler = VectorAssembler(
    inputCols=list(delay_X_train.columns),
    outputCol="features")

if "features" in delay_X_train.columns:
  delay_X_train.drop(columns=["features"], inplace=True)

labeled_X_train = delay_X_train
labeled_X_train['result'] = delay_y_train
training = vecAssembler.transform(spark.createDataFrame(labeled_X_train))

# TODO: create an MLLib LinearRegression with the appropriate features and predictions
lr = LinearRegression(featuresCol="features", labelCol="result")

lr.fit(training)
# Out:
# LinearRegressionModel: uid=LinearRegression_ce554dee131c, numFeatures=633

# %%
df2 = training[['features','result']].take(3)

grader.grade('ml_features', str(df2))
# Out:
# Correct! You earned 1/1 points. You are a star!
#
# Your submission has been successfully recorded in the gradebook.

# %% [markdown]
# Let's see if prediction works!

# %%
from pyspark.sql.functions import pandas_udf
import pandas as pd
import numpy as np
import traceback

def convert_to_batch(series: np.ndarray) -> np.ndarray:
  """
  Helper function to convert from PySpark (which sends a pd.Series of components)
  to an ndarray.
  """
  X_batch_list = []
  model_local = bc_model.value # This is our shared ML model, broadcast

  for i, v_raw in enumerate(series):
      # Expecting v_raw to be a numpy.ndarray of shape (4,)
      # containing [type_code, size, indices_array, values_array]
      if isinstance(v_raw, np.ndarray) and v_raw.shape == (4,):
          vector_type_code = v_raw[0]
          vector_size = v_raw[1]
          indices = v_raw[2]
          values = v_raw[3]

          if vector_type_code == 0: # Sparse vector
              if not isinstance(indices, np.ndarray) or not isinstance(values, np.ndarray):
                  X_batch_list.append(np.full(model_local.n_features_in_, np.nan))
                  continue

              dense_vector = np.zeros(vector_size, dtype=float)
              # Populate the dense vector from sparse components
              for idx, val in zip(indices, values):
                  dense_vector[idx] = val
              X_batch_list.append(dense_vector)
          elif vector_type_code == 1: # Dense vector (values is already the dense array)
              if isinstance(values, np.ndarray):
                  X_batch_list.append(values)
              else:
                    X_batch_list.append(np.full(model_local.n_features_in_, np.nan))
          else:
              X_batch_list.append(np.full(model_local.n_features_in_, np.nan))
      else:
          # Fallback if feature count can be determined
          if hasattr(model_local, 'n_features_in_'):
              X_batch_list.append(np.full(model_local.n_features_in_, np.nan))
          else:
              raise TypeError("Cannot process vector elements and model feature count is unknown.")

  return np.vstack(X_batch_list)


@pandas_udf("float")
def predict_delays(features_series: pd.Series) -> pd.Series:
    """
    Pandas UDF to run scikit-learn linear regression on a batch of Spark Vectors.
    """
    try:
        if features_series.empty:
            return pd.Series([np.nan] * 1)

        X_batch = convert_to_batch(features_series.values)
        if X_batch.size == 0:
            return pd.Series([np.nan] * len(features_series))

        model = bc_model.value
        if not hasattr(model, 'coef_') or not hasattr(model, 'n_features_in_'):
            raise AttributeError("Broadcasted model does not have expected 'coef_' or 'n_features_in_' attributes.")

        if X_batch.shape[1] != model.n_features_in_:
            raise ValueError(f"Feature count mismatch: X_batch has {X_batch.shape[1]} features, but model expects {model.n_features_in_}.")

        predictions = model.predict(X_batch)
        return pd.Series(predictions)

    except Exception as e:
        return pd.Series([np.nan] * len(features_series))

bc_model = spark.sparkContext.broadcast(regr)

df = data.withColumn("predicted_y", predict_delays(data['features']))
df.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1573951000.py in <cell line: 0>()
#      76 bc_model = spark.sparkContext.broadcast(regr)
#      77
# ---> 78 df = data.withColumn("predicted_y", predict_delays(data['features']))
#      79 df.show()
#
# NameError: name 'data' is not defined
